# %% [markdown]
# # **SlowFast Network Model with APD Framework-Detailed Explanation of the Code Process**
#
# # **Step 1: Library Installation and Imports**
# # Install necessary libraries for object detection (YOLOv5), video processing (OpenCV), and deep learning (PyTorch).
# # Import additional modules for lane detection, motion analysis, and video generation.
#
# # **Step 2: Lane Detection**
# # Uses Canny edge detection and Hough Line Transform to detect lane lines in video frames.
# # This enhances the frame by highlighting the road lanes.
#
# # **Step 3: Object Detection and Bounding Boxes**
# # YOLOv5 model detects objects (e.g., cars, pedestrians) in each frame.
# # Draws bounding boxes around detected objects and labels them with class names and confidence scores.
#
# # **Step 4: Absolute Pixel Difference - Image Similarity Assessment**
# # Calculates frame similarity using frame difference and thresholds.
# # Frames with minimal changes are skipped to optimize processing time and computational resources.
#
# # **Step 5: SlowFast Model Input Preparation**
# # Prepares frames for the SlowFast model by creating "fast" and "slow" pathways.
# # This facilitates detailed analysis of video content across multiple temporal scales.
#
# # **Step 6: Video Processing Workflow**
# # Reads video frames, applies lane detection, object detection, and motion analysis.
# # Writes processed frames to the output video, skipping similar frames based on adaptive thresholds.
#
# # **Step 7: Performance Metrics**
# # Calculates and displays metrics like the total number of frames processed, skipped frame percentage, and FPS.
# # These metrics provide insights into the efficiency of the video processing pipeline.
#
# # **Step 8: Dynamic Video Generation**
# # Saves the processed video with highlighted lanes, objects, and dynamically adapted frame rates.
# # Output video is optimized for use in applications like traffic monitoring or surveillance.

# %%
# Set the video paths
video_path = '/content/00067cfb-e535423e.mov'  # Input video file path
output_video_path = '/content/processed_APD_video.mp4'  # Output video path

# Install required libraries
# !pip install torch torchvision pytorchvideo opencv-python scikit-image ultralytics

import torch
import torchvision.transforms as transforms
import cv2
import numpy as np
from pytorchvideo.models.hub import slowfast_r50  # SlowFast
from ultralytics import YOLO  # For YOLOv5
import time  # To calculate FPS

# Load YOLOv5 model
yolo_model = YOLO("yolov5s.pt")

# Load the SlowFast model
model = slowfast_r50(pretrained=True)
model.eval()

# Transform for SlowFast model input
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((256, 256)),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.45, 0.45, 0.45], std=[0.225, 0.225, 0.225]),
])

# Function to detect lanes using Canny edge detection and Hough line transform
def detect_lanes(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    edges = cv2.Canny(blurred, 50, 150)
    height, width = frame.shape[:2]
    roi_vertices = np.array([[(0.1 * width, height), (0.9 * width, height),
                              (0.55 * width, 0.6 * height), (0.45 * width, 0.6 * height)]], dtype=np.int32)
    mask = np.zeros_like(edges)
    cv2.fillPoly(mask, roi_vertices, 255)
    masked_edges = cv2.bitwise_and(edges, mask)
    lines = cv2.HoughLinesP(masked_edges, 1, np.pi / 180, threshold=50, minLineLength=50, maxLineGap=25)
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(frame, (x1, y1), (x2, y2), (0, 255, 0), 5)
    return frame

# Function to draw bounding boxes and labels on the frame for detected objects
def draw_bounding_boxes(frame, results):
    class_names = yolo_model.names
    for obj in results:
        cls = int(obj.cls[0])
        label = class_names[cls]
        x1, y1, x2, y2 = map(int, obj.xyxy[0].tolist())
        confidence = obj.conf[0] * 100
        cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 0), 2)
        label_text = f"{label}: {confidence:.2f}%"
        cv2.putText(frame, label_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
    return frame

# Function to detect and crop the closest object using YOLO
def detect_and_crop(image):
    results = yolo_model(image)
    image_with_boxes = draw_bounding_boxes(image.copy(), results[0].boxes)
    return image_with_boxes

# Function to calculate frame difference with motion thresholding
def calculate_frame_difference(frame1, frame2):
    # Calculate the absolute difference between frames
    diff = cv2.absdiff(frame1, frame2)

    # Thresholding to count significant changes
    _, diff = cv2.threshold(diff, 30, 255, cv2.THRESH_BINARY)  # Ignore low-intensity changes
    non_zero_count = np.count_nonzero(diff)
    change_ratio = non_zero_count / frame1.size

    return 1 - change_ratio  # Higher values indicate lower motion

# Function to extract frames for SlowFast (fast and slow pathways)
def prepare_slowfast_inputs(frames, slow_rate=16):
    fast_pathway = frames
    slow_pathway = frames[::slow_rate]
    fast_tensor = torch.stack(fast_pathway).unsqueeze(0)
    slow_tensor = torch.stack(slow_pathway).unsqueeze(0)
    return [slow_tensor, fast_tensor]

# Process video with YOLO, SlowFast, and ADP for dynamic framerate
def process_video(input_path, output_path, adp_threshold=0.8750):
    cap = cv2.VideoCapture(input_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    prev_frame = None  # Track the last processed frame
    last_processed_index = -1  # To track the index of the last processed frame
    frame_count = 0
    skipped_frames = 0
    processed_frames = 0

    start_time = time.time()

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_with_lanes = detect_lanes(frame)
        frame_with_objects = detect_and_crop(frame_with_lanes)
        transformed_frame = transform(frame_with_objects)

        if frame_count == 0:  # First frame, always process it
            prev_frame = frame_with_objects
            out.write(frame_with_objects)  # Write first frame
            processed_frames += 1
            last_processed_index = frame_count
        else:
            # Calculate similarity with the last processed frame
            difference = calculate_frame_difference(prev_frame, frame_with_objects)
            print(f"Comparing frame {last_processed_index} with frame {frame_count}: similarity score = {difference:.4f}")

            if difference < adp_threshold:  # Process the frame if the difference is low
                prev_frame = frame_with_objects  # Update previous frame to current
                processed_frames += 1
                out.write(frame_with_objects)  # Write processed frame
                last_processed_index = frame_count  # Update the last processed frame index
            else:  # Frame is similar, skip
                print(f"Skipping frame {frame_count}, difference: {difference:.4f}")
                skipped_frames += 1
                # Do not update prev_frame, so we compare the next unprocessed frame with the last processed frame

        frame_count += 1  # Increment frame count

    cap.release()
    out.release()

    end_time = time.time()
    total_time = end_time - start_time
    video_fps = processed_frames / total_time if total_time > 0 else 0

    total_frames = frame_count  # Count of all frames read
    metrics = {
        'Total Frames': total_frames,
        'No of Frames Skipped': skipped_frames,
        '% of Frames Skipped': (skipped_frames / total_frames) * 100 if total_frames > 0 else 0,
        'FPS': video_fps,
    }

    print("Metrics:")
    print(f"Total Frames = {metrics['Total Frames']}")
    print(f"No of Frames Skipped = {metrics['No of Frames Skipped']}")
    print(f"% of Frames Skipped = {metrics['% of Frames Skipped']:.2f}%")
    print(f"FPS = {metrics['FPS']:.2f}")

# Run the video processing function
process_video(video_path, output_video_path)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640
9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 130 with frame 132: similarity score = 0.8362
#
# 0: 384x640 12 persons, 5 cars, 1 truck, 3 traffic lights, 1 handbag, 336.3ms
# Speed: 3.1ms preprocess, 336.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 132 with frame 133: similarity score = 0.8945
# Skipping frame 133, difference: 0.8945
#
# 0: 384x640 12 persons, 5 cars, 1 truck, 3 traffic lights, 2 handbags, 344.7ms
# Speed: 4.0ms preprocess, 344.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 132 with frame 134: similarity score = 0.8353
#
# 0: 384x640 11 persons, 5 cars, 1 truck, 1 traffic light, 333.6ms
# Speed: 2.7ms preprocess, 333.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 134 with frame 135: similarity score = 0.8796
# Skipping frame 135, difference: 0.8796
#
# 0: 384x640 12 persons, 4 cars, 1 truck, 1 traffic light, 448.8ms
# Speed: 2.8ms preprocess, 448.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 134 with frame 136: similarity score = 0.8189
#
# 0: 384x640 10 persons, 5 cars, 1 truck, 2 traffic lights, 1 handbag, 553.1ms
# Speed: 3.2ms preprocess, 553.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 136 with frame 137: similarity score = 0.8803
# Skipping frame 137, difference: 0.8803
#
# 0: 384x640 11 persons, 6 cars, 1 truck, 2 traffic lights, 518.3ms
# Speed: 3.3ms preprocess, 518.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 136 with frame 138: similarity score = 0.8184
#
# 0: 384x640 14 persons, 4 cars, 1 truck, 2 traffic lights, 654.1ms
# Speed: 20.4ms preprocess, 654.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 138 with frame 139: similarity score = 0.8624
#
# 0: 384x640 12 persons, 5 cars, 1 truck, 2 traffic lights, 574.5ms
# Speed: 3.5ms preprocess, 574.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 139 with frame 140: similarity score = 0.8695
#
# 0: 384x640 15 persons, 4 cars, 1 truck, 2 traffic lights, 529.1ms
# Speed: 3.5ms preprocess, 529.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 140 with frame 141: similarity score = 0.8766
# Skipping frame 141, difference: 0.8766
#
# 0: 384x640 14 persons, 4 cars, 1 truck, 2 traffic lights, 1 backpack, 365.3ms
# Speed: 4.3ms preprocess, 365.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 140 with frame 142: similarity score = 0.8126
#
# 0: 384x640 11 persons, 3 cars, 1 truck, 1 traffic light, 333.6ms
# Speed: 3.3ms preprocess, 333.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 142 with frame 143: similarity score = 0.8607
#
# 0: 384x640 11 persons, 5 cars, 1 truck, 1 traffic light, 337.2ms
# Speed: 3.0ms preprocess, 337.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 143 with frame 144: similarity score = 0.8745
#
# 0: 384x640 8 persons, 4 cars, 1 truck, 1 traffic light, 339.7ms
# Speed: 5.1ms preprocess, 339.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 144 with frame 145: similarity score = 0.8697
#
# 0: 384x640 8 persons, 5 cars, 1 truck, 1 traffic light, 319.4ms
# Speed: 4.8ms preprocess, 319.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 145 with frame 146: similarity score = 0.8706
#
# 0: 384x640 9 persons, 5 cars, 1 truck, 2 traffic lights, 350.1ms
# Speed: 2.6ms preprocess, 350.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 146 with frame 147: similarity score = 0.8758
# Skipping frame 147, difference: 0.8758
#
# 0: 384x640 10 persons, 5 cars, 1 truck, 3 traffic lights, 332.5ms
# Speed: 5.1ms preprocess, 332.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 146 with frame 148: similarity score = 0.8105
#
# 0: 384x640 7 persons, 5 cars, 1 truck, 3 traffic lights, 333.5ms
# Speed: 4.3ms preprocess, 333.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 148 with frame 149: similarity score = 0.8768
# Skipping frame 149, difference: 0.8768
#
# 0: 384x640 7 persons, 4 cars, 1 truck, 3 traffic lights, 353.1ms
# Speed: 4.4ms preprocess, 353.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 148 with frame 150: similarity score = 0.8181
#
# 0: 384x640 10 persons, 5 cars, 1 truck,
9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 242 with frame 243: similarity score = 0.8425
#
# 0: 384x640 6 persons, 7 cars, 1 truck, 2 traffic lights, 353.9ms
# Speed: 5.1ms preprocess, 353.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 243 with frame 244: similarity score = 0.8429
#
# 0: 384x640 7 persons, 7 cars, 1 truck, 2 traffic lights, 333.9ms
# Speed: 2.9ms preprocess, 333.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 244 with frame 245: similarity score = 0.8434
#
# 0: 384x640 5 persons, 7 cars, 1 truck, 2 traffic lights, 1 suitcase, 335.0ms
# Speed: 3.0ms preprocess, 335.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 245 with frame 246: similarity score = 0.8421
#
# 0: 384x640 6 persons, 5 cars, 1 truck, 2 traffic lights, 348.9ms
# Speed: 3.6ms preprocess, 348.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 246 with frame 247: similarity score = 0.8456
#
# 0: 384x640 4 persons, 7 cars, 1 truck, 1 traffic light, 329.0ms
# Speed: 3.7ms preprocess, 329.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 247 with frame 248: similarity score = 0.8511
#
# 0: 384x640 6 persons, 7 cars, 1 truck, 1 traffic light, 359.5ms
# Speed: 5.6ms preprocess, 359.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 248 with frame 249: similarity score = 0.8605
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 1 traffic light, 338.4ms
# Speed: 4.1ms preprocess, 338.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 249 with frame 250: similarity score = 0.8640
#
# 0: 384x640 6 persons, 9 cars, 1 truck, 1 traffic light, 338.7ms
# Speed: 5.5ms preprocess, 338.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 250 with frame 251: similarity score = 0.8626
#
# 0: 384x640 5 persons, 7 cars, 1 truck, 349.4ms
# Speed: 3.1ms preprocess, 349.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 251 with frame 252: similarity score = 0.8649
#
# 0: 384x640 7 persons, 7 cars, 1 truck, 323.7ms
# Speed: 3.3ms preprocess, 323.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 252 with frame 253: similarity score = 0.8691
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 389.6ms
# Speed: 3.4ms preprocess, 389.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 253 with frame 254: similarity score = 0.8680
#
# 0: 384x640 5 persons, 6 cars, 1 bus, 1 truck, 329.3ms
# Speed: 3.1ms preprocess, 329.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 254 with frame 255: similarity score = 0.8645
#
# 0: 384x640 7 persons, 8 cars, 1 truck, 346.6ms
# Speed: 3.8ms preprocess, 346.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 255 with frame 256: similarity score = 0.8590
#
# 0: 384x640 6 persons, 9 cars, 1 truck, 347.7ms
# Speed: 3.6ms preprocess, 347.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 256 with frame 257: similarity score = 0.8618
#
# 0: 384x640 6 persons, 9 cars, 1 truck, 350.9ms
# Speed: 3.6ms preprocess, 350.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 257 with frame 258: similarity score = 0.8652
#
# 0: 384x640 5 persons, 8 cars, 1 truck, 508.0ms
# Speed: 6.8ms preprocess, 508.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 258 with frame 259: similarity score = 0.8682
#
# 0: 384x640 5 persons, 6 cars, 1 truck, 510.0ms
# Speed: 3.5ms preprocess, 510.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 259 with frame 260: similarity score = 0.8729
#
# 0: 384x640 5 persons, 9 cars, 1 truck, 524.6ms
# Speed: 3.1ms preprocess, 524.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 260 with frame 261: similarity score = 0.8785
# Skipping frame 261, difference: 0.8785
#
# 0: 384x640 7 persons, 10 cars, 1 truck, 540.3ms
# Speed: 3.2ms preprocess, 540.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 260 with frame 262: similarity score = 0.8328
#
# 0: 384x640 5 persons, 9 cars, 1 truck, 528.6ms
# Speed: 3.2ms preprocess, 528.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 262 with frame 263: similarity score = 0.8833
# Skipping frame 263, difference: 0.8833
#
# 0: 384x640 6 persons, 8 cars, 1 truck, 1 traffic light, 560.5ms
# Speed: 4.5ms preprocess, 560.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 262 with frame 264: similarity score = 0.8314
#
# 0: 384x640 9 persons, 7 cars, 1 truck, 385.3ms
# Speed: 5.3ms preprocess, 385.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame
6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 303 with frame 304: similarity score = 0.9006
# Skipping frame 304, difference: 0.9006
#
# 0: 384x640 7 persons, 6 cars, 1 truck, 345.1ms
# Speed: 3.2ms preprocess, 345.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 303 with frame 305: similarity score = 0.8513
#
# 0: 384x640 9 persons, 7 cars, 1 bus, 1 truck, 1 traffic light, 326.9ms
# Speed: 5.8ms preprocess, 326.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 305 with frame 306: similarity score = 0.9047
# Skipping frame 306, difference: 0.9047
#
# 0: 384x640 10 persons, 8 cars, 1 truck, 360.2ms
# Speed: 3.6ms preprocess, 360.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 305 with frame 307: similarity score = 0.8589
#
# 0: 384x640 6 persons, 9 cars, 1 truck, 327.7ms
# Speed: 4.6ms preprocess, 327.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 307 with frame 308: similarity score = 0.9077
# Skipping frame 308, difference: 0.9077
#
# 0: 384x640 8 persons, 9 cars, 1 truck, 2 handbags, 334.3ms
# Speed: 3.1ms preprocess, 334.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 307 with frame 309: similarity score = 0.8595
#
# 0: 384x640 9 persons, 8 cars, 1 truck, 1 handbag, 340.9ms
# Speed: 4.0ms preprocess, 340.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 309 with frame 310: similarity score = 0.9076
# Skipping frame 310, difference: 0.9076
#
# 0: 384x640 8 persons, 8 cars, 1 truck, 1 traffic light, 2 handbags, 319.3ms
# Speed: 3.6ms preprocess, 319.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 309 with frame 311: similarity score = 0.8574
#
# 0: 384x640 8 persons, 10 cars, 1 truck, 1 traffic light, 343.1ms
# Speed: 3.0ms preprocess, 343.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 311 with frame 312: similarity score = 0.9017
# Skipping frame 312, difference: 0.9017
#
# 0: 384x640 8 persons, 8 cars, 1 truck, 345.5ms
# Speed: 3.8ms preprocess, 345.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 311 with frame 313: similarity score = 0.8523
#
# 0: 384x640 7 persons, 5 cars, 1 truck, 343.4ms
# Speed: 3.2ms preprocess, 343.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 313 with frame 314: similarity score = 0.8972
# Skipping frame 314, difference: 0.8972
#
# 0: 384x640 8 persons, 13 cars, 1 truck, 1 traffic light, 348.6ms
# Speed: 3.0ms preprocess, 348.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 313 with frame 315: similarity score = 0.8475
#
# 0: 384x640 9 persons, 10 cars, 1 truck, 1 traffic light, 1 parking meter, 325.5ms
# Speed: 3.2ms preprocess, 325.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 315 with frame 316: similarity score = 0.8928
# Skipping frame 316, difference: 0.8928
#
# 0: 384x640 9 persons, 11 cars, 1 truck, 1 traffic light, 1 handbag, 352.3ms
# Speed: 3.2ms preprocess, 352.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 315 with frame 317: similarity score = 0.8455
#
# 0: 384x640 10 persons, 13 cars, 1 truck, 1 traffic light, 345.3ms
# Speed: 3.7ms preprocess, 345.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 317 with frame 318: similarity score = 0.8952
# Skipping frame 318, difference: 0.8952
#
# 0: 384x640 9 persons, 11 cars, 1 bus, 1 truck, 1 handbag, 346.2ms
# Speed: 5.4ms preprocess, 346.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 317 with frame 319: similarity score = 0.8416
#
# 0: 384x640 10 persons, 10 cars, 1 bus, 1 truck, 1 handbag, 408.6ms
# Speed: 5.6ms preprocess, 408.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 319 with frame 320: similarity score = 0.8990
# Skipping frame 320, difference: 0.8990
#
# 0: 384x640 9 persons, 6 cars, 1 bus, 1 truck, 1 handbag, 552.4ms
# Speed: 4.0ms preprocess, 552.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# ...
# Comparing frame 1142 with frame 1144: similarity score = 0.9013
# Skipping frame 1144, difference: 0.9013
#
# 0: 384x640 8 persons, 4 cars, 2 buss, 2 traffic lights, 350.5ms
# Speed: 3.0ms preprocess, 350.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1142 with frame 1145: similarity score = 0.8669
#
# 0: 384x640 7 persons, 4 cars, 2 buss, 2 traffic lights, 1 backpack, 347.8ms
# Speed: 3.0ms preprocess, 347.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1145 with frame 1146: similarity score = 0.9442
# Skipping frame 1146, difference: 0.9442
#
# 0: 384x640 7 persons, 5 cars, 2 buss, 2 traffic lights, 327.1ms
# Speed: 5.4ms preprocess, 327.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1145 with frame 1147: similarity score = 0.9098
# Skipping frame 1147, difference: 0.9098
#
# 0: 384x640 11 persons, 5 cars, 2 buss, 2 traffic lights, 337.0ms
# Speed: 3.9ms preprocess, 337.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1145 with frame 1148: similarity score = 0.8942
# Skipping frame 1148, difference: 0.8942
#
# 0: 384x640 11 persons, 4 cars, 2 buss, 2 traffic lights, 362.0ms
# Speed: 3.3ms preprocess, 362.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1145 with frame 1149: similarity score = 0.8750
#
# 0: 384x640 12 persons, 4 cars, 4 buss, 2 traffic lights, 350.7ms
# Speed: 4.0ms preprocess, 350.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1149 with frame 1150: similarity score = 0.9433
# Skipping frame 1150, difference: 0.9433
#
# 0: 384x640 10 persons, 4 cars, 4 buss, 2 traffic lights, 484.5ms
# Speed: 4.6ms preprocess, 484.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1149 with frame 1151: similarity score = 0.9186
# Skipping frame 1151, difference: 0.9186
#
# 0: 384x640 11 persons, 4 cars, 2 buss, 2 traffic lights, 543.2ms
# Speed: 7.4ms preprocess, 543.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1149 with frame 1152: similarity score = 0.9057
# Skipping frame 1152, difference: 0.9057
#
# 0: 384x640 11 persons, 4 cars, 2 buss, 2 traffic lights, 531.8ms
# Speed: 3.1ms preprocess, 531.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1149 with frame 1153: similarity score = 0.8924
# Skipping frame 1153, difference: 0.8924
#
# 0: 384x640 9 persons, 6 cars, 2 buss, 2 traffic lights, 535.4ms
# Speed: 7.2ms preprocess, 535.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1149 with frame 1154: similarity score = 0.8768
# Skipping frame 1154, difference: 0.8768
#
# 0: 384x640 9 persons, 4 cars, 2 buss, 3 traffic lights, 530.4ms
# Speed: 3.2ms preprocess, 530.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1149 with frame 1155: similarity score = 0.8630
#
# 0: 384x640 11 persons, 5 cars, 2 buss, 3 traffic lights, 573.1ms
# Speed: 3.2ms preprocess, 573.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1155 with frame 1156: similarity score = 0.9416
# Skipping frame 1156, difference: 0.9416
#
# 0: 384x640 8 persons, 4 cars, 2 buss, 3 traffic lights, 451.7ms
# Speed: 3.7ms preprocess, 451.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1155 with frame 1157: similarity score = 0.9302
# Skipping frame 1157, difference: 0.9302
#
# 0: 384x640 10 persons, 5 cars, 2 buss, 3 traffic lights, 355.7ms
# Speed: 4.2ms preprocess, 355.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1155 with frame 1158: similarity score = 0.9134
# Skipping frame 1158, difference: 0.9134
#
# 0: 384x640 8 persons, 4 cars, 2 buss, 3 traffic lights, 340.3ms
# Speed: 3.1ms preprocess, 340.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1155 with frame 1159: similarity score = 0.9010
# Skipping frame 1159, difference: 0.9010
#
# 0: 384x640 9 persons, 4 cars, 2 buss, 3 traffic lights, 375.6ms
# Speed: 3.6ms preprocess, 375.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1155 with frame 1160: similarity score = 0.8862
# Skipping frame 1160, difference: 0.8862
#
# 0: 384x640 9 persons, 4 cars, 2 buss, 3 traffic lights, 344.9ms
# Speed: 3.7ms preprocess, 344.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1155 with frame 1161: similarity score = 0.8710
#
# 0: 384x640 13 persons, 4 cars, 2 buss, 2 traffic lights, 344.1ms
# Speed: 4.0ms preprocess, 344.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1161 with frame 1162: similarity score = 0.9430
# Skipping frame 1162, difference: 0.9430
#
# 0: 384x640 10 persons, 5 cars, 2 buss, 2 traffic lights, 353.0ms
# Speed: 3.1ms preprocess, 353.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1161 with frame 1163: similarity score = 0.9176
# Skipping frame 1163, difference: 0.9176
#
# 0: 384x640 11 persons, 5 cars, 2 buss, 2 traffic lights, 323.2ms
# Speed: 2.7ms preprocess, 323.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1161 with frame 1164: similarity score = 0.9003
# Skipping frame 1164, difference: 0.9003
#
# 0: 384x640 13 persons, 5 cars, 2 buss, 2 traffic lights, 355.5ms
# Speed: 3.2ms preprocess, 355.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1161 with frame 1165: similarity score = 0.8827
# Skipping frame 1165, difference: 0.8827
#
# 0: 384x640 12 persons, 5 cars, 2 buss, 2 traffic lights, 334.0ms
# Speed: 3.3ms preprocess, 334.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1161 with frame 1166: similarity score = 0.8733
#
# 0: 384x640 9 persons, 5 cars, 1 bus, 2 traffic lights, 324.3ms
# Speed: 3.5ms preprocess, 324.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1166 with frame 1167: similarity score = 0.9436
# Skipping frame 1167, difference: 0.9436
#
# 0: 384x640 9 persons, 5 cars, 2 buss, 2 traffic lights, 345.0ms
# Speed: 3.5ms preprocess, 345.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1166 with frame 1168: similarity score = 0.9221
# Skipping frame 1168, difference: 0.9221
#
# 0: 384x640 8 persons, 5 cars, 2 buss, 2 traffic lights, 1 handbag, 336.0ms
# Speed: 3.8ms preprocess, 336.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1166 with frame 1169: similarity score = 0.8991
# Skipping frame 1169, difference: 0.8991
#
# 0: 384x640 10 persons, 6 cars, 2 buss, 2 traffic lights, 1 handbag, 361.0ms
# Speed: 3.2ms preprocess, 361.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1166 with frame 1170: similarity score = 0.8785
# Skipping frame 1170, difference: 0.8785
#
# 0: 384x640 8 persons, 6 cars, 2 buss, 2 traffic lights, 429.2ms
# Speed: 3.6ms preprocess, 429.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1166 with frame 1171: similarity score = 0.8601
#
# 0: 384x640 8 persons, 6 cars, 1 bus, 2 traffic lights, 424.2ms
# Speed: 5.1ms preprocess, 424.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1171 with frame 1172: similarity score = 0.9432
# Skipping frame 1172, difference: 0.9432
#
# 0: 384x640 8 persons, 7 cars, 1 bus, 2 traffic lights, 385.7ms
# Speed: 4.1ms preprocess, 385.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1171 with frame 1173: similarity score = 0.9135
# Skipping frame 1173, difference: 0.9135
#
# 0: 384x640 10 persons, 9 cars, 1 bus, 2 traffic lights, 1 handbag, 404.4ms
# Speed: 6.5ms preprocess, 404.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1171 with frame 1174: similarity score = 0.8828
# Skipping frame 1174, difference: 0.8828
#
# 0: 384x640 7 persons, 7 cars, 1 bus, 2 traffic lights, 389.7ms
# Speed: 5.7ms preprocess, 389.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1171 with frame 1175: similarity score = 0.8652
#
# 0: 384x640 7 persons, 6 cars, 1 bus, 2 traffic lights, 394.1ms
# Speed: 4.9ms preprocess, 394.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1175 with frame 1176: similarity score = 0.9377
# Skipping frame 1176, difference: 0.9377
#
# 0: 384x640 8 persons, 6 cars, 1 bus, 2 traffic lights, 418.3ms
# Speed: 5.4ms preprocess, 418.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1175 with frame 1177: similarity score = 0.9142
# Skipping frame 1177, difference: 0.9142
#
# 0: 384x640 8 persons, 6 cars, 1 bus, 2 traffic lights, 404.2ms
# Speed: 3.7ms preprocess, 404.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1175 with frame 1178: similarity score = 0.8974
# Skipping frame 1178, difference: 0.8974
#
# 0: 384x640 8 persons, 5 cars, 1 bus, 3 traffic lights, 430.4ms
# Speed: 6.2ms preprocess, 430.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1175 with frame 1179: similarity score = 0.8735
#
# 0: 384x640 8 persons, 5 cars, 1 bus, 3 traffic lights, 613.0ms
# Speed: 5.8ms preprocess, 613.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1179 with frame 1180: similarity score = 0.9377
# Skipping frame 1180, difference: 0.9377
#
# 0: 384x640 8 persons, 7 cars, 1 bus, 2 traffic lights, 648.9ms
# Speed: 3.3ms preprocess, 648.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1179 with frame 1181: similarity score = 0.9115
# Skipping frame 1181, difference: 0.9115
#
# 0: 384x640 8 persons, 7 cars, 1 bus, 2 traffic lights, 671.6ms
# Speed: 3.3ms preprocess, 671.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1179 with frame 1182: similarity score = 0.8948
# Skipping frame 1182, difference: 0.8948
#
# 0: 384x640 8 persons, 6 cars, 2 buss, 2 traffic lights, 680.1ms
# Speed: 5.2ms preprocess, 680.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1179 with frame 1183: similarity score = 0.8766
# Skipping frame 1183, difference: 0.8766
#
# 0: 384x640 8 persons, 6 cars, 1 bus, 2 traffic lights, 905.3ms
# Speed: 3.5ms preprocess, 905.3ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1179 with frame 1184: similarity score = 0.8586
#
# 0: 384x640 10 persons, 8 cars, 1 bus, 2 traffic lights, 859.2ms
# Speed: 3.2ms preprocess, 859.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1184 with frame 1185: similarity score = 0.9455
# Skipping frame 1185, difference: 0.9455
#
# 0: 384x640 8 persons, 7 cars, 2 traffic lights, 606.2ms
# Speed: 3.2ms preprocess, 606.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1184 with frame 1186: similarity score = 0.9232
# Skipping frame 1186, difference: 0.9232
#
# 0: 384x640 8 persons, 6 cars, 1 bus, 1 truck, 2 traffic lights, 677.7ms
# Speed: 3.5ms preprocess, 677.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1184 with frame 1187: similarity score = 0.8981
# Skipping frame 1187, difference: 0.8981
#
# 0: 384x640 8 persons, 7 cars, 3 traffic lights, 415.7ms
# Speed: 3.2ms preprocess, 415.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1184 with frame 1188: similarity score = 0.8751
# Skipping frame 1188, difference: 0.8751
#
# 0: 384x640 9 persons, 7 cars, 2 traffic lights, 343.2ms
# Speed: 3.6ms preprocess, 343.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1184 with frame 1189: similarity score = 0.8560
#
# 0: 384x640 7 persons, 7 cars, 1 truck, 3 traffic lights, 1 kite, 356.5ms
# Speed: 4.1ms preprocess, 356.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1189 with frame 1190: similarity score = 0.9303
# Skipping frame 1190, difference: 0.9303
#
# 0: 384x640 7 persons, 7 cars, 1 bus, 1 truck, 3 traffic lights, 333.6ms
# Speed: 3.5ms preprocess, 333.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1189 with frame 1191: similarity score = 0.8992
# Skipping frame 1191, difference: 0.8992
#
# 0: 384x640 9 persons, 8 cars, 1 bus, 1 truck, 3 traffic lights, 1 kite, 363.5ms
# Speed: 5.4ms preprocess, 363.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1189 with frame 1192: similarity score = 0.8688
#
# 0: 384x640 9 persons, 7 cars, 1 truck, 3 traffic lights, 341.0ms
# Speed: 4.4ms preprocess, 341.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1192 with frame 1193: similarity score = 0.9267
# Skipping frame 1193, difference: 0.9267
#
# 0: 384x640 9 persons, 8 cars, 1 bus, 1 truck, 3 traffic lights, 362.6ms
# Speed: 3.5ms preprocess, 362.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1192 with frame 1194: similarity score = 0.8968
# Skipping frame 1194, difference: 0.8968
#
# 0: 384x640 9 persons, 6 cars, 1 truck, 2 traffic lights, 347.0ms
# Speed: 3.1ms preprocess, 347.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1192 with frame 1195: similarity score = 0.8631
#
# 0: 384x640 8 persons, 6 cars, 1 truck, 2 traffic lights, 337.4ms
# Speed: 4.1ms preprocess, 337.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1195 with frame 1196: similarity score = 0.9276
# Skipping frame 1196, difference: 0.9276
#
# 0: 384x640 10 persons, 6 cars, 1 truck, 3 traffic lights, 364.9ms
# Speed: 3.1ms preprocess, 364.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1195 with frame 1197: similarity score = 0.8897
# Skipping frame 1197, difference: 0.8897
#
# 0: 384x640 10 persons, 6 cars, 1 truck, 3 traffic lights, 337.3ms
# Speed: 3.4ms preprocess, 337.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1195 with frame 1198: similarity score = 0.8632
#
# 0: 384x640 10 persons, 6 cars, 1 truck, 3 traffic lights, 354.1ms
# Speed: 3.1ms preprocess, 354.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1198 with frame 1199: similarity score = 0.9255
# Skipping frame 1199, difference: 0.9255
#
# 0: 384x640 9 persons, 7 cars, 2 trucks, 2 traffic lights, 355.8ms
# Speed: 3.8ms preprocess, 355.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1198 with frame 1200: similarity score = 0.8925
# Skipping frame 1200, difference: 0.8925
#
# 0: 384x640 7 persons, 6 cars, 1 truck, 2 traffic lights, 332.2ms
# Speed: 3.3ms preprocess, 332.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1198 with frame 1201: similarity score = 0.8658
#
# 0: 384x640 9 persons, 6 cars, 1 truck, 2 traffic lights, 358.0ms
# Speed: 2.7ms preprocess, 358.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1201 with frame 1202: similarity score = 0.9305
# Skipping frame 1202, difference: 0.9305
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 2 traffic lights, 325.7ms
# Speed: 3.0ms preprocess, 325.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1201 with frame 1203: similarity score = 0.8994
# Skipping frame 1203, difference: 0.8994
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 2 traffic lights, 349.7ms
# Speed: 4.1ms preprocess, 349.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1201 with frame 1204: similarity score = 0.8722
#
# 0: 384x640 6 persons, 3 cars, 1 truck, 2 traffic lights, 347.2ms
# Speed: 3.1ms preprocess, 347.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Comparing frame 1204 with frame 1205: similarity score = 0.9411
# Skipping frame 1205, difference: 0.9411
# Metrics:
# Total Frames = 1206
# No of Frames Skipped = 662
# % of Frames Skipped = 54.89%
# FPS = 1.00
