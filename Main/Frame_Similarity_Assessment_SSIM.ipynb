# %% [markdown]
# # **SSIM Frame Similarity - Detailed Process Explanation**
#
# # **Step 1: Import Libraries**
# # Import required libraries for video processing (OpenCV), memory and CPU profiling (psutil), and structural similarity computation (SSIM from skimage).
# # These libraries are essential for video frame comparison, performance monitoring, and efficient memory management during video processing.
#
# # **Step 2: SSIM Frame Similarity Function**
# # A function to compute the Structural Similarity Index (SSIM) score between two video frames.
# # SSIM measures perceptual similarity, which is useful for deciding whether two frames are similar enough to skip processing.
#
# # **Step 3: Video Frame Extraction**
# # Function to extract and convert video frames into grayscale.
# # The frames are read from the input video, stored in a list, and then used for SSIM-based frame comparison.
#
# # **Step 4: Video Frame Loading and Time Calculation**
# # Load video frames and measure the time it takes for this process.
# # The function `get_video_frames` returns a list of grayscale frames which are necessary for comparison.
# # The time to load all frames from the video is recorded to evaluate performance.
#
# # **Step 5: Video Writer Setup**
# # A video writer is initialized to save the processed video.
# # Set the codec and output video file format (`.mp4`), and extract the frame size and frame rate from the first frame.
#
# # **Step 6: Frame Processing and Comparison**
# # Loop through each frame of the video starting from frame 1.
# # Compare each current frame with the last processed frame using the SSIM score.
# # If SSIM score is high (indicating high similarity), the frame is skipped; otherwise, it is processed and written to the output video.
#
# # **Step 7: CPU Usage Tracking**
# # Track CPU usage for each frame comparison during video processing.
# # The psutil library is used to record CPU usage, which is stored for later calculation of average CPU usage during the entire processing period.
#
# # **Step 8: Metrics Collection**
# # After processing, calculate and log the following:
# #  - Total frames processed and skipped
# #  - Frame processing time (loading, processing, and total)
# #  - Memory consumption before and after processing (using psutil)
# #  - Average CPU usage during processing
# # These metrics help assess the performance and efficiency of the video processing pipeline.
#
# # **Step 9: Final Results and Logging**
# # Print detailed statistics regarding the processing of the video, including the number of frames processed, skipped, and the percentage of skipped frames.
# # Additionally, log time-related details such as processing FPS, total time, and memory consumption during processing to evaluate efficiency.
#
# # **Step 10: Video Writing and Resource Cleanup**
# # The processed video is saved to the specified output path.
# # Release the video writer after finishing processing and writing the frames.

# %%
# Dry run

import cv2
import numpy as np
import time
import psutil  # For memory and CPU profiling
from skimage.metrics import structural_similarity as ssim  # Import SSIM from skimage

# Set the video path (update this to your video file path)
video_path = '/content/input 1.mov'  # Change this to your video file path
output_video_path = '/content/Output_SSIM.mp4'  # Output video path

# Function to calculate the SSIM between two frames
def calculate_ssim(frame1, frame2):
    # Calculate SSIM
    score, _ = ssim(frame1, frame2, full=True)
    return score

# Read video frames
def get_video_frames(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
        frames.append(gray_frame)
    cap.release()
    return frames

# Load video frames
start_time = time.time()  # Start time for reading frames
frames = get_video_frames(video_path)
loading_time = time.time() - start_time  # Time taken to load frames

# Set up the video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
fps = 30  # Set to your video's frame rate
frame_height, frame_width = frames[0].shape
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Process frames and write to output video
frame_count = len(frames)
skipped_frames = 0
processed_frames = 0
out.write(cv2.cvtColor(frames[0], cv2.COLOR_GRAY2BGR))  # Write the first frame
last_processed_frame_index = 0  # Track the last processed frame index

# Start time for processing and initialize CPU usage tracking
start_processing_time = time.time()
cpu_usage_samples = []

# Start comparing from frame 1 onwards
for i in range(1, frame_count):
    # Compare current frame with the last processed frame
    current_frame = frames[i]
    last_frame = frames[last_processed_frame_index]

    ssim_score = calculate_ssim(last_frame, current_frame)
    # Record CPU usage for the current comparison
    cpu_usage_samples.append(psutil.cpu_percent(interval=None))
    print(f"Comparing Frame {last_processed_frame_index} with Frame {i}: SSIM = {ssim_score:.4f}")

    if ssim_score >= 0.75:  # If SSIM score is high, skip the current frame
        skipped_frames += 1
    else:  # If SSIM score is low, process the current frame
        out.write(cv2.cvtColor(current_frame, cv2.COLOR_GRAY2BGR))  # Write the current frame if not similar
        last_processed_frame_index = i  # Update the last processed frame index to the current frame
        processed_frames += 1  # Count the processed frame

# Calculate processing time
end_processing_time = time.time()
processing_time = end_processing_time - start_processing_time
total_time = loading_time + processing_time  # Total time includes loading and processing

# Release the video writer
out.release()

# Memory usage before and after processing
process = psutil.Process()
memory_info = process.memory_info()
initial_memory = memory_info.rss / (1024 * 1024)  # Convert bytes to MB
final_memory = (memory_info.rss + (skipped_frames * frames[0].nbytes)) / (1024 * 1024)  # Rough estimate of final memory
memory_consumed = final_memory - initial_memory

# Calculate average CPU usage during processing
average_cpu_usage = np.mean(cpu_usage_samples)

# Log the required information
print(f"Processed video saved as: {output_video_path}")
print(f"Total number of frames: {frame_count}")
print(f"Number of frames skipped: {skipped_frames}")
print(f"Number of frames processed: {processed_frames}")
print(f"% of frames skipped: {(skipped_frames / frame_count) * 100:.2f}%")
print(f"Frames processing per second: {frame_count / processing_time:.2f} FPS")
print(f"Total time taken to load frames: {loading_time:.6f} seconds")
print(f"Total processing time: {processing_time:.6f} seconds")
print(f"Total time (loading + processing): {total_time:.6f} seconds")
print(f"Average time per frame comparison: {processing_time / (frame_count - 1):.6f} seconds")
print(f"Total memory usage: Initial = {initial_memory:.2f} MB, Final = {final_memory:.2f} MB")
print(f"Memory consumed during processing: {memory_consumed:.2f} MB")
print(f"Average CPU usage during processing: {average_cpu_usage:.2f}%")
print(f"Total processing load: {frame_count} frames")
# Out:
# Comparing Frame 0 with Frame 1: SSIM = 0.6387
# Comparing Frame 1 with Frame 2: SSIM = 0.6485
# Comparing Frame 2 with Frame 3: SSIM = 0.6398
# Comparing Frame 3 with Frame 4: SSIM = 0.6276
# Comparing Frame 4 with Frame 5: SSIM = 0.6400
# Comparing Frame 5 with Frame 6: SSIM = 0.7784
# Comparing Frame 5 with Frame 7: SSIM = 0.6590
# Comparing Frame 7 with Frame 8: SSIM = 0.7831
# Comparing Frame 7 with Frame 9: SSIM = 0.6707
# Comparing Frame 9 with Frame 10: SSIM = 0.7782
# Comparing Frame 9 with Frame 11: SSIM = 0.6772
# Comparing Frame 11 with Frame 12: SSIM = 0.7975
# Comparing Frame 11 with Frame 13: SSIM = 0.6737
# Comparing Frame 13 with Frame 14: SSIM = 0.7681
# Comparing Frame 13 with Frame 15: SSIM = 0.6276
# Comparing Frame 15 with Frame 16: SSIM = 0.7383
# Comparing Frame 16 with Frame 17: SSIM = 0.7351
# Comparing Frame 17 with Frame 18: SSIM = 0.6984
# Comparing Frame 18 with Frame 19: SSIM = 0.7144
# Comparing Frame 19 with Frame 20: SSIM = 0.7097
# Comparing Frame 20 with Frame 21: SSIM = 0.6899
# Comparing Frame 21 with Frame 22: SSIM = 0.6711
# Comparing Frame 22 with Frame 23: SSIM = 0.6642
# Comparing Frame 23 with Frame 24: SSIM = 0.6543
# Comparing Frame 24 with Frame 25: SSIM = 0.6548
# Comparing Frame 25 with Frame 26: SSIM = 0.6487
# Comparing Frame 26 with Frame 27: SSIM = 0.6474
# Comparing Frame 27 with Frame 28: SSIM = 0.6603
# Comparing Frame 28 with Frame 29: SSIM = 0.6732
# Comparing Frame 29 with Frame 30: SSIM = 0.6851
# Comparing Frame 30 with Frame 31: SSIM = 0.6777
# Comparing Frame 31 with Frame 32: SSIM = 0.6900
# Comparing Frame 32 with Frame 33: SSIM = 0.6821
# Comparing Frame 33 with Frame 34: SSIM = 0.6725
# Comparing Frame 34 with Frame 35: SSIM = 0.6715
# Comparing Frame 35 with Frame 36: SSIM = 0.6590
# Comparing Frame 36 with Frame 37: SSIM = 0.6618
# Comparing Frame 37 with Frame 38: SSIM = 0.6620
# Comparing Frame 38 with Frame 39: SSIM = 0.6396
# Comparing Frame 39 with Frame 40: SSIM = 0.6192
# Comparing Frame 40 with Frame 41: SSIM = 0.6138
# Comparing Frame 41 with Frame 42: SSIM = 0.6106
# Comparing Frame 42 with Frame 43: SSIM = 0.5862
# Comparing Frame 43 with Frame 44: SSIM = 0.5973
# Comparing Frame 44 with Frame 45: SSIM = 0.6364
# Comparing Frame 45 with Frame 46: SSIM = 0.6464
# Comparing Frame 46 with Frame 47: SSIM = 0.6646
# Comparing Frame 47 with Frame 48: SSIM = 0.6896
# Comparing Frame 48 with Frame 49: SSIM = 0.7039
# Comparing Frame 49 with Frame 50: SSIM = 0.7055
# Comparing Frame 50 with Frame 51: SSIM = 0.7288
# Comparing Frame 51 with Frame 52: SSIM = 0.7066
# Comparing Frame 52 with Frame 53: SSIM = 0.7356
# Comparing Frame 53 with Frame 54: SSIM = 0.7135
# Comparing Frame 54 with Frame 55: SSIM = 0.7344
# Comparing Frame 55 with Frame 56: SSIM = 0.6885
# Comparing Frame 56 with Frame 57: SSIM = 0.7102
# Comparing Frame 57 with Frame 58: SSIM = 0.6839
# Comparing Frame 58 with Frame 59: SSIM = 0.6853
# Comparing Frame 59 with Frame 60: SSIM = 0.6787
# Comparing Frame 60 with Frame 61: SSIM = 0.6768
# Comparing Frame 61 with Frame 62: SSIM = 0.6698
# Comparing Frame 62 with Frame 63: SSIM = 0.6758
# Comparing Frame 63 with Frame 64: SSIM = 0.7013
# Comparing Frame 64 with Frame 65: SSIM = 0.6875
# Comparing Frame 65 with Frame 66: SSIM = 0.6836
# Comparing Frame 66 with Frame 67: SSIM = 0.6754
# Comparing Frame 67 with Frame 68: SSIM = 0.6901
# Comparing Frame 68 with Frame 69: SSIM = 0.6815
# Comparing Frame 69 with Frame 70: SSIM = 0.6787
# Comparing Frame 70 with Frame 71: SSIM = 0.6886
# Comparing Frame 71 with Frame 72: SSIM = 0.7166
# Comparing Frame 72 with Frame 73: SSIM = 0.6978
# Comparing Frame 73 with Frame 74: SSIM = 0.7144
# Comparing Frame 74 with Frame 75: SSIM = 0.7227
# Comparing Frame 75 with Frame 76: SSIM = 0.7618
# Comparing Frame 75 with Frame 77: SSIM = 0.6364
# Comparing Frame 77 with Frame 78: SSIM = 0.7502
# Comparing Frame 77 with Frame 79: SSIM = 0.6060
# Comparing Frame 79 with Frame 80: SSIM = 0.7372
# Comparing Frame 80 with Frame 81: SSIM = 0.7594
# Comparing Frame 80 with Frame 82: SSIM = 0.6063
# Comparing Frame 82 with Frame 83: SSIM = 0.7158
# Comparing Frame 83 with Frame 84: SSIM = 0.6959
# Comparing Frame 84 with Frame 85: SSIM = 0.7001
# Comparing Frame 85 with Frame 86: SSIM = 0.6539
# Comparing Frame 86 with Frame 87: SSIM = 0.6352
# Comparing Frame 87 with Frame 88: SSIM = 0.6206
# Comparing Frame 88 with Frame 89: SSIM = 0.5974
# Comparing Frame 89 with Frame 90: SSIM = 0.5842
# Comparing Frame 90 with Frame 91: SSIM = 0.5772
# Comparing Frame 91 with Frame 92: SSIM = 0.5883
# Comparing Frame 92 with Frame 93: SSIM = 0.6253
# Comparing Frame 93 with Frame 94: SSIM = 0.7072
# Comparing Frame 94 with Frame 95: SSIM = 0.6878
# Comparing Frame 95 with Frame 96: SSIM = 0.7016
# Comparing Frame 96 with Frame 97: SSIM = 0.7328
# Comparing Frame 97 with Frame 98: SSIM = 0.7807
# Comparing Frame 97 with Frame 99: SSIM = 0.5864
# Comparing Frame 99 with Frame 100: SSIM = 0.7418
# Comparing Frame 100 with Frame 101: SSIM = 0.7767
# Comparing Frame 100 with Frame 102: SSIM = 0.6372
# Comparing Frame 102 with Frame 103: SSIM = 0.7225
# Comparing Frame 103 with Frame 104: SSIM = 0.7458
# Comparing Frame 104 with Frame 105: SSIM = 0.7824
# Comparing Frame 104 with Frame 106: SSIM = 0.6320
# Comparing Frame 106 with Frame 107: SSIM = 0.7263
# Comparing Frame 107 with Frame 108: SSIM = 0.7480
# Comparing Frame 108 with Frame 109: SSIM = 0.6680
# Comparing Frame 109 with Frame 110: SSIM = 0.7459
# Comparing Frame 110 with Frame 111: SSIM = 0.7273
# Comparing Frame 111 with Frame 112: SSIM = 0.6982
# Comparing Frame 112 with Frame 113: SSIM = 0.7784
# Comparing Frame 112 with Frame 114: SSIM = 0.6541
# Comparing Frame 114 with Frame 115: SSIM = 0.8162
# Comparing Frame 114 with Frame 116: SSIM = 0.6649
# Comparing Frame 116 with Frame 117: SSIM = 0.7748
# Comparing Frame 116 with Frame 118: SSIM = 0.6445
# Comparing Frame 118 with Frame 119: SSIM = 0.7866
# Comparing Frame 118 with Frame 120: SSIM = 0.6377
# Comparing Frame 120 with Frame 121: SSIM = 0.7852
# Comparing Frame 120 with Frame 122: SSIM = 0.6363
# Comparing Frame 122 with Frame 123: SSIM = 0.7155
# Comparing Frame 123 with Frame 124: SSIM = 0.7615
# Comparing Frame 123 with Frame 125: SSIM = 0.6041
# Comparing Frame 125 with Frame 126: SSIM = 0.7537
# Comparing Frame 125 with Frame 127: SSIM = 0.6220
# Comparing Frame 127 with Frame 128: SSIM = 0.7101
# Comparing Frame 128 with Frame 129: SSIM = 0.7231
# Comparing Frame 129 with Frame 130: SSIM = 0.7405
# Comparing Frame 130 with Frame 131: SSIM = 0.7393
# Comparing Frame 131 with Frame 132: SSIM = 0.7435
# Comparing Frame 132 with Frame 133: SSIM = 0.7689
# Comparing Frame 132 with Frame 134: SSIM = 0.5951
# Comparing Frame 134 with Frame 135: SSIM = 0.7230
# Comparing Frame 135 with Frame 136: SSIM = 0.7388
# Comparing Frame 136 with Frame 137: SSIM = 0.7270
# Comparing Frame 137 with Frame 138: SSIM = 0.7052
# Comparing Frame 138 with Frame 139: SSIM = 0.6652
# Comparing Frame 139 with Frame 140: SSIM = 0.6749
# Comparing Frame 140 with Frame 141: SSIM = 0.6958
# Comparing Frame 141 with Frame 142: SSIM = 0.6597
# Comparing Frame 142 with Frame 143: SSIM = 0.6438
# Comparing Frame 143 with Frame 144: SSIM = 0.6619
# Comparing Frame 144 with Frame 145: SSIM = 0.6454
# Comparing Frame 145 with Frame 146: SSIM = 0.6354
# Comparing Frame 146 with Frame 147: SSIM = 0.6530
# Comparing Frame 147 with Frame 148: SSIM = 0.6653
# Comparing Frame 148 with Frame 149: SSIM = 0.6881
# Comparing Frame 149 with Frame 150: SSIM = 0.6912
# Comparing Frame 150 with Frame 151: SSIM = 0.6987
# Comparing Frame 151 with Frame 152: SSIM = 0.7120
# Comparing Frame 152 with Frame 153: SSIM = 0.6838
# Comparing Frame 153 with Frame 154: SSIM = 0.6825
# Comparing Frame 154 with Frame 155: SSIM = 0.6582
# Comparing Frame 155 with Frame 156: SSIM = 0.6711
# Comparing Frame 156 with Frame 157: SSIM = 0.6628
# Comparing Frame 157 with Frame 158: SSIM = 0.6598
# Comparing Frame 158 with Frame 159: SSIM = 0.6665
# Comparing Frame 159 with Frame 160: SSIM = 0.6414
# Comparing Frame 160 with Frame 161: SSIM = 0.6482
# Comparing Frame 161 with Frame 162: SSIM = 0.6505
# Comparing Frame 162 with Frame 163: SSIM = 0.6425
# Comparing Frame 163 with Frame 164: SSIM = 0.6479
# Comparing Frame 164 with Frame 165: SSIM = 0.6490
# Comparing Frame 165 with Frame 166: SSIM = 0.6422
# Comparing Frame 166 with Frame 167: SSIM = 0.6333
# Comparing Frame 167 with Frame 168: SSIM = 0.6232
# Comparing Frame 168 with Frame 169: SSIM = 0.6148
# Comparing Frame 169 with Frame 170: SSIM = 0.6168
# Comparing Frame 170 with Frame 171: SSIM = 0.5987
# Comparing Frame 171 with Frame 172: SSIM = 0.6012
# Comparing Frame 172 with Frame 173: SSIM = 0.6009
# Comparing Frame 173 with Frame 174: SSIM = 0.6015
# Comparing Frame 174 with Frame 175: SSIM = 0.6080
# Comparing Frame 175 with Frame 176: SSIM = 0.6093
# Comparing Frame 176 with Frame 177: SSIM = 0.6057
# Comparing Frame 177 with Frame 178: SSIM = 0.6009
# Comparing Frame 178 with Frame 179: SSIM = 0.6141
# Comparing Frame 179 with Frame 180: SSIM = 0.6316
# Comparing Frame 180 with Frame 181: SSIM = 0.6499
# Comparing Frame 181 with Frame 182: SSIM = 0.6704
# Comparing Frame 182 with Frame 183: SSIM = 0.6722
# Comparing Frame 183 with Frame 184: SSIM = 0.6643
# Comparing Frame 184 with Frame 185: SSIM = 0.6786
# Comparing Frame 185 with Frame 186: SSIM = 0.6739
# Comparing Frame 186 with Frame 187: SSIM = 0.6451
# Comparing Frame 187 with Frame 188: SSIM = 0.6506
# Comparing Frame 188 with Frame 189: SSIM = 0.6373
# Comparing Frame 189 with Frame 190: SSIM = 0.6310
# Comparing Frame 190 with Frame 191: SSIM = 0.6300
# Comparing Frame 191 with Frame 192: SSIM = 0.6246
# Comparing Frame 192 with Frame 193: SSIM = 0.6311
# Comparing Frame 193 with Frame 194: SSIM = 0.6313
# Comparing Frame 194 with Frame 195: SSIM = 0.6287
# Comparing Frame 195 with Frame 196: SSIM = 0.6332
# Comparing Frame 196 with Frame 197: SSIM = 0.6346
# Comparing Frame 197 with Frame 198: SSIM = 0.6283
# Comparing Frame 198 with Frame 199: SSIM = 0.6309
# Comparing Frame 199 with Frame 200: SSIM = 0.6344
# Comparing Frame 200 with Frame 201: SSIM = 0.6361
# Comparing Frame 201 with Frame 202: SSIM = 0.6316
# Comparing Frame 202 with Frame 203: SSIM = 0.6042
# Comparing Frame 203 with Frame 204: SSIM = 0.5998
# Comparing Frame 204 with Frame 205: SSIM = 0.5862
# Comparing Frame 205 with Frame 206: SSIM = 0.5777
# Comparing Frame 206 with Frame 207: SSIM = 0.5703
# Comparing Frame 207 with Frame 208: SSIM = 0.5648
# Comparing Frame 208 with Frame 209: SSIM = 0.5636
# Comparing Frame 209 with Frame 210: SSIM = 0.5656
# Comparing Frame 210 with Frame 211: SSIM = 0.5691
# Comparing Frame 211 with Frame 212: SSIM = 0.5741
# Comparing Frame 212 with Frame 213: SSIM = 0.5767
# Comparing Frame 213 with Frame 214: SSIM = 0.5825
# Comparing Frame 214 with Frame 215: SSIM = 0.5854
# Comparing Frame 215 with Frame 216: SSIM = 0.5924
# Comparing Frame 216 with Frame 217: SSIM = 0.5951
# Comparing Frame 217 with Frame 218: SSIM = 0.5947
# Comparing Frame 218 with Frame 219: SSIM = 0.5858
# Comparing Frame 219 with Frame 220: SSIM = 0.5955
# Comparing Frame 220 with Frame 221: SSIM = 0.5917
# Comparing Frame 221 with Frame 222: SSIM = 0.5772
# Comparing Frame 222 with Frame 223: SSIM = 0.5707
# Comparing Frame 223 with Frame 224: SSIM = 0.5640
# Comparing Frame 224 with Frame 225: SSIM = 0.5660
# Comparing Frame 225 with Frame 226: SSIM = 0.5771
# Comparing Frame 226 with Frame 227: SSIM = 0.5907
# Comparing Frame 227 with Frame 228: SSIM = 0.6008
# Comparing Frame 228 with Frame 229: SSIM = 0.5974
# Comparing Frame 229 with Frame 230: SSIM = 0.5952
# Comparing Frame 230 with Frame 231: SSIM = 0.5903
# Comparing Frame 231 with Frame 232: SSIM = 0.5937
# Comparing Frame 232 with Frame 233: SSIM = 0.5852
# Comparing Frame 233 with Frame 234: SSIM = 0.5758
# Comparing Frame 234 with Frame 235: SSIM = 0.5606
# Comparing Frame 235 with Frame 236: SSIM = 0.5631
# Comparing Frame 236 with Frame 237: SSIM = 0.5734
# Comparing Frame 237 with Frame 238: SSIM = 0.5853
# Comparing Frame 238 with Frame 239: SSIM = 0.5930
# Comparing Frame 239 with Frame 240: SSIM = 0.6046
# Comparing Frame 240 with Frame 241: SSIM = 0.6151
# Comparing Frame 241 with Frame 242: SSIM = 0.6081
# Comparing Frame 242 with Frame 243: SSIM = 0.6017
# Comparing Frame 243 with Frame 244: SSIM = 0.6044
# Comparing Frame 244 with Frame 245: SSIM = 0.5896
# Comparing Frame 245 with Frame 246: SSIM = 0.5967
# Comparing Frame 246 with Frame 247: SSIM = 0.6052
# Comparing Frame 247 with Frame 248: SSIM = 0.6157
# Comparing Frame 248 with Frame 249: SSIM = 0.6196
# Comparing Frame 249 with Frame 250: SSIM = 0.6308
# Comparing Frame 250 with Frame 251: SSIM = 0.6229
# Comparing Frame 251 with Frame 252: SSIM = 0.6248
# Comparing Frame 252 with Frame 253: SSIM = 0.6385
# Comparing Frame 253 with Frame 254: SSIM = 0.6328
# Comparing Frame 254 with Frame 255: SSIM = 0.6285
# Comparing Frame 255 with Frame 256: SSIM = 0.6229
# Comparing Frame 256 with Frame 257: SSIM = 0.6326
# Comparing Frame 257 with Frame 258: SSIM = 0.6343
# Comparing Frame 258 with Frame 259: SSIM = 0.6413
# Comparing Frame 259 with Frame 260: SSIM = 0.6568
# Comparing Frame 260 with Frame 261: SSIM = 0.6685
# Comparing Frame 261 with Frame 262: SSIM = 0.6838
# Comparing Frame 262 with Frame 263: SSIM = 0.6885
# Comparing Frame 263 with Frame 264: SSIM = 0.6805
# Comparing Frame 264 with Frame 265: SSIM = 0.6746
# Comparing Frame 265 with Frame 266: SSIM = 0.6649
# Comparing Frame 266 with Frame 267: SSIM = 0.6516
# Comparing Frame 267 with Frame 268: SSIM = 0.6503
# Comparing Frame 268 with Frame 269: SSIM = 0.6642
# Comparing Frame 269 with Frame 270: SSIM = 0.6748
# Comparing Frame 270 with Frame 271: SSIM = 0.6882
# Comparing Frame 271 with Frame 272: SSIM = 0.7061
# Comparing Frame 272 with Frame 273: SSIM = 0.7217
# Comparing Frame 273 with Frame 274: SSIM = 0.7266
# Comparing Frame 274 with Frame 275: SSIM = 0.7337
# Comparing Frame 275 with Frame 276: SSIM = 0.7279
# Comparing Frame 276 with Frame 277: SSIM = 0.7291
# Comparing Frame 277 with Frame 278: SSIM = 0.7338
# Comparing Frame 278 with Frame 279: SSIM = 0.7337
# Comparing Frame 279 with Frame 280: SSIM = 0.7333
# Comparing Frame 280 with Frame 281: SSIM = 0.7433
# Comparing Frame 281 with Frame 282: SSIM = 0.7509
# Comparing Frame 281 with Frame 283: SSIM = 0.6023
# Comparing Frame 283 with Frame 284: SSIM = 0.7699
# Comparing Frame 283 with Frame 285: SSIM = 0.6195
# Comparing Frame 285 with Frame 286: SSIM = 0.7924
# Comparing Frame 285 with Frame 287: SSIM = 0.6280
# Comparing Frame 287 with Frame 288: SSIM = 0.8061
# Comparing Frame 287 with Frame 289: SSIM = 0.6210
# Comparing Frame 289 with Frame 290: SSIM = 0.7753
# Comparing Frame 289 with Frame 291: SSIM = 0.5889
# Comparing Frame 291 with Frame 292: SSIM = 0.7809
# Comparing Frame 291 with Frame 293: SSIM = 0.6008
# Comparing Frame 293 with Frame 294: SSIM = 0.7981
# Comparing Frame 293 with Frame 295: SSIM = 0.6232
# Comparing Frame 295 with Frame 296: SSIM = 0.8090
# Comparing Frame 295 with Frame 297: SSIM = 0.6405
# Comparing Frame 297 with Frame 298: SSIM = 0.7937
# Comparing Frame 297 with Frame 299: SSIM = 0.6200
# Comparing Frame 299 with Frame 300: SSIM = 0.7670
# Comparing Frame 299 with Frame 301: SSIM = 0.6101
# Comparing Frame 301 with Frame 302: SSIM = 0.7603
# Comparing Frame 301 with Frame 303: SSIM = 0.6087
# Comparing Frame 303 with Frame 304: SSIM = 0.7656
# Comparing Frame 303 with Frame 305: SSIM = 0.6099
# Comparing Frame 305 with Frame 306: SSIM = 0.7864
# Comparing Frame 305 with Frame 307: SSIM = 0.6229
# Comparing Frame 307 with Frame 308: SSIM = 0.8002
# Comparing Frame 307 with Frame 309: SSIM = 0.6303
# Comparing Frame 309 with Frame 310: SSIM = 0.7980
# Comparing Frame 309 with Frame 311: SSIM = 0.6287
# Comparing Frame 311 with Frame 312: SSIM = 0.7776
# Comparing Frame 311 with Frame 313: SSIM = 0.6169
# Comparing Frame 313 with Frame 314: SSIM = 0.7528
# Comparing Frame 313 with Frame 315: SSIM = 0.6001
# Comparing Frame 315 with Frame 316: SSIM = 0.7459
# Comparing Frame 316 with Frame 317: SSIM = 0.7544
# Comparing Frame 316 with Frame 318: SSIM = 0.6176
# Comparing Frame 318 with Frame 319: SSIM = 0.7586
# Comparing Frame 318 with Frame 320: SSIM = 0.6170
# Comparing Frame 320 with Frame 321: SSIM = 0.7779
# Comparing Frame 320 with Frame 322: SSIM = 0.6253
# Comparing Frame 322 with Frame 323: SSIM = 0.7760
# Comparing Frame 322 with Frame 324: SSIM = 0.6298
# Comparing Frame 324 with Frame 325: SSIM = 0.7776
# Comparing Frame 324 with Frame 326: SSIM = 0.6273
# Comparing Frame 326 with Frame 327: SSIM = 0.7569
# Comparing Frame 326 with Frame 328: SSIM = 0.6096
# Comparing Frame 328 with Frame 329: SSIM = 0.7458
# Comparing Frame 329 with Frame 330: SSIM = 0.7434
# Comparing Frame 330 with Frame 331: SSIM = 0.7416
# Comparing Frame 331 with Frame 332: SSIM = 0.7550
# Comparing Frame 331 with Frame 333: SSIM = 0.6042
# Comparing Frame 333 with Frame 334: SSIM = 0.7660
# Comparing Frame 333 with Frame 335: SSIM = 0.6161
# Comparing Frame 335 with Frame 336: SSIM = 0.7602
# Comparing Frame 335 with Frame 337: SSIM = 0.6092
# Comparing Frame 337 with Frame 338: SSIM = 0.7666
# Comparing Frame 337 with Frame 339: SSIM = 0.6132
# Comparing Frame 339 with Frame 340: SSIM = 0.7531
# Comparing Frame 339 with Frame 341: SSIM = 0.6106
# Comparing Frame 341 with Frame 342: SSIM = 0.7563
# Comparing Frame 341 with Frame 343: SSIM = 0.6127
# Comparing Frame 343 with Frame 344: SSIM = 0.7587
# Comparing Frame 343 with Frame 345: SSIM = 0.6127
# Comparing Frame 345 with Frame 346: SSIM = 0.7528
# Comparing Frame 345 with Frame 347: SSIM = 0.5977
# Comparing Frame 347 with Frame 348: SSIM = 0.7585
# Comparing Frame 347 with Frame 349: SSIM = 0.6010
# Comparing Frame 349 with Frame 350: SSIM = 0.7558
# Comparing Frame 349 with Frame 351: SSIM = 0.5997
# Comparing Frame 351 with Frame 352: SSIM = 0.7503
# Comparing Frame 351 with Frame 353: SSIM = 0.5896
# Comparing Frame 353 with Frame 354: SSIM = 0.7491
# Comparing Frame 354 with Frame 355: SSIM = 0.7434
# Comparing Frame 355 with Frame 356: SSIM = 0.7340
# Comparing Frame 356 with Frame 357: SSIM = 0.7344
# Comparing Frame 357 with Frame 358: SSIM = 0.7267
# Comparing Frame 358 with Frame 359: SSIM = 0.7210
# Comparing Frame 359 with Frame 360: SSIM = 0.7284
# Comparing Frame 360 with Frame 361: SSIM = 0.7303
# Comparing Frame 361 with Frame 362: SSIM = 0.7201
# Comparing Frame 362 with Frame 363: SSIM = 0.7260
# Comparing Frame 363 with Frame 364: SSIM = 0.7339
# Comparing Frame 364 with Frame 365: SSIM = 0.7283
# Comparing Frame 365 with Frame 366: SSIM = 0.7054
# Comparing Frame 366 with Frame 367: SSIM = 0.6745
# Comparing Frame 367 with Frame 368: SSIM = 0.6673
# Comparing Frame 368 with Frame 369: SSIM = 0.6567
# Comparing Frame 369 with Frame 370: SSIM = 0.6337
# Comparing Frame 370 with Frame 371: SSIM = 0.6491
# Comparing Frame 371 with Frame 372: SSIM = 0.6178
# Comparing Frame 372 with Frame 373: SSIM = 0.6152
# Comparing Frame 373 with Frame 374: SSIM = 0.6099
# Comparing Frame 374 with Frame 375: SSIM = 0.6065
# Comparing Frame 375 with Frame 376: SSIM = 0.5992
# Comparing Frame 376 with Frame 377: SSIM = 0.5970
# Comparing Frame 377 with Frame 378: SSIM = 0.5770
# Comparing Frame 378 with Frame 379: SSIM = 0.5714
# Comparing Frame 379 with Frame 380: SSIM = 0.5680
# Comparing Frame 380 with Frame 381: SSIM = 0.5666
# Comparing Frame 381 with Frame 382: SSIM = 0.5753
# Comparing Frame 382 with Frame 383: SSIM = 0.5656
# Comparing Frame 383 with Frame 384: SSIM = 0.5614
# Comparing Frame 384 with Frame 385: SSIM = 0.5734
# Comparing Frame 385 with Frame 386: SSIM = 0.5655
# Comparing Frame 386 with Frame 387: SSIM = 0.5553
# Comparing Frame 387 with Frame 388: SSIM = 0.5521
# Comparing Frame 388 with Frame 389: SSIM = 0.5434
# Comparing Frame 389 with Frame 390: SSIM = 0.5407
# Comparing Frame 390 with Frame 391: SSIM = 0.5369
# Comparing Frame 391 with Frame 392: SSIM = 0.5378
# Comparing Frame 392 with Frame 393: SSIM = 0.5423
# Comparing Frame 393 with Frame 394: SSIM = 0.5456
# Comparing Frame 394 with Frame 395: SSIM = 0.5500
# Comparing Frame 395 with Frame 396: SSIM = 0.5629
# Comparing Frame 396 with Frame 397: SSIM = 0.5681
# Comparing Frame 397 with Frame 398: SSIM = 0.5719
# Comparing Frame 398 with Frame 399: SSIM = 0.5782
# Comparing Frame 399 with Frame 400: SSIM = 0.5798
# Comparing Frame 400 with Frame 401: SSIM = 0.5834
# Comparing Frame 401 with Frame 402: SSIM = 0.5851
# Comparing Frame 402 with Frame 403: SSIM = 0.5822
# Comparing Frame 403 with Frame 404: SSIM = 0.5793
# Comparing Frame 404 with Frame 405: SSIM = 0.5808
# Comparing Frame 405 with Frame 406: SSIM = 0.5796
# Comparing Frame 406 with Frame 407: SSIM = 0.5793
# Comparing Frame 407 with Frame 408: SSIM = 0.5781
# Comparing Frame 408 with Frame 409: SSIM = 0.5773
# Comparing Frame 409 with Frame 410: SSIM = 0.5690
# Comparing Frame 410 with Frame 411: SSIM = 0.5659
# Comparing Frame 411 with Frame 412: SSIM = 0.5604
# Comparing Frame 412 with Frame 413: SSIM = 0.5672
# Comparing Frame 413 with Frame 414: SSIM = 0.5708
# Comparing Frame 414 with Frame 415: SSIM = 0.5738
# Comparing Frame 415 with Frame 416: SSIM = 0.5717
# Comparing Frame 416 with Frame 417: SSIM = 0.5693
# Comparing Frame 417 with Frame 418: SSIM = 0.5712
# Comparing Frame 418 with Frame 419: SSIM = 0.5764
# Comparing Frame 419 with Frame 420: SSIM = 0.5803
# Comparing Frame 420 with Frame 421: SSIM = 0.5902
# Comparing Frame 421 with Frame 422: SSIM = 0.6026
# Comparing Frame 422 with Frame 423: SSIM = 0.6076
# Comparing Frame 423 with Frame 424: SSIM = 0.6182
# Comparing Frame 424 with Frame 425: SSIM = 0.6301
# Comparing Frame 425 with Frame 426: SSIM = 0.6354
# Comparing Frame 426 with Frame 427: SSIM = 0.6273
# Comparing Frame 427 with Frame 428: SSIM = 0.6209
# Comparing Frame 428 with Frame 429: SSIM = 0.6130
# Comparing Frame 429 with Frame 430: SSIM = 0.6079
# Comparing Frame 430 with Frame 431: SSIM = 0.6043
# Comparing Frame 431 with Frame 432: SSIM = 0.6012
# Comparing Frame 432 with Frame 433: SSIM = 0.5990
# Comparing Frame 433 with Frame 434: SSIM = 0.6011
# Comparing Frame 434 with Frame 435: SSIM = 0.6013
# Comparing Frame 435 with Frame 436: SSIM = 0.5982
# Comparing Frame 436 with Frame 437: SSIM = 0.5979
# Comparing Frame 437 with Frame 438: SSIM = 0.5978
# Comparing Frame 438 with Frame 439: SSIM = 0.5992
# Comparing Frame 439 with Frame 440: SSIM = 0.6039
# Comparing Frame 440 with Frame 441: SSIM = 0.6078
# Comparing Frame 441 with Frame 442: SSIM = 0.6119
# Comparing Frame 442 with Frame 443: SSIM = 0.6120
# Comparing Frame 443 with Frame 444: SSIM = 0.6124
# Comparing Frame 444 with Frame 445: SSIM = 0.6151
# Comparing Frame 445 with Frame 446: SSIM = 0.5988
# Comparing Frame 446 with Frame 447: SSIM = 0.5983
# Comparing Frame 447 with Frame 448: SSIM = 0.6038
# Comparing Frame 448 with Frame 449: SSIM = 0.6132
# Comparing Frame 449 with Frame 450: SSIM = 0.6159
# Comparing Frame 450 with Frame 451: SSIM = 0.6146
# Comparing Frame 451 with Frame 452: SSIM = 0.6225
# Comparing Frame 452 with Frame 453: SSIM = 0.6287
# Comparing Frame 453 with Frame 454: SSIM = 0.6407
# Comparing Frame 454 with Frame 455: SSIM = 0.6496
# Comparing Frame 455 with Frame 456: SSIM = 0.6553
# Comparing Frame 456 with Frame 457: SSIM = 0.6648
# Comparing Frame 457 with Frame 458: SSIM = 0.6740
# Comparing Frame 458 with Frame 459: SSIM = 0.6644
# Comparing Frame 459 with Frame 460: SSIM = 0.6633
# Comparing Frame 460 with Frame 461: SSIM = 0.6769
# Comparing Frame 461 with Frame 462: SSIM = 0.6799
# Comparing Frame 462 with Frame 463: SSIM = 0.6838
# Comparing Frame 463 with Frame 464: SSIM = 0.6836
# Comparing Frame 464 with Frame 465: SSIM = 0.6749
# Comparing Frame 465 with Frame 466: SSIM = 0.6690
# Comparing Frame 466 with Frame 467: SSIM = 0.6717
# Comparing Frame 467 with Frame 468: SSIM = 0.6713
# Comparing Frame 468 with Frame 469: SSIM = 0.6663
# Comparing Frame 469 with Frame 470: SSIM = 0.6720
# Comparing Frame 470 with Frame 471: SSIM = 0.6697
# Comparing Frame 471 with Frame 472: SSIM = 0.6497
# Comparing Frame 472 with Frame 473: SSIM = 0.6369
# Comparing Frame 473 with Frame 474: SSIM = 0.6211
# Comparing Frame 474 with Frame 475: SSIM = 0.5979
# Comparing Frame 475 with Frame 476: SSIM = 0.6184
# Comparing Frame 476 with Frame 477: SSIM = 0.6030
# Comparing Frame 477 with Frame 478: SSIM = 0.5973
# Comparing Frame 478 with Frame 479: SSIM = 0.6131
# Comparing Frame 479 with Frame 480: SSIM = 0.6050
# Comparing Frame 480 with Frame 481: SSIM = 0.6322
# Comparing Frame 481 with Frame 482: SSIM = 0.6322
# Comparing Frame 482 with Frame 483: SSIM = 0.6392
# Comparing Frame 483 with Frame 484: SSIM = 0.6212
# Comparing Frame 484 with Frame 485: SSIM = 0.6021
# Comparing Frame 485 with Frame 486: SSIM = 0.5978
# Comparing Frame 486 with Frame 487: SSIM = 0.5860
# Comparing Frame 487 with Frame 488: SSIM = 0.5889
# Comparing Frame 488 with Frame 489: SSIM = 0.6011
# Comparing Frame 489 with Frame 490: SSIM = 0.5864
# Comparing Frame 490 with Frame 491: SSIM = 0.5640
# Comparing Frame 491 with Frame 492: SSIM = 0.5623
# Comparing Frame 492 with Frame 493: SSIM = 0.5623
# Comparing Frame 493 with Frame 494: SSIM = 0.5587
# Comparing Frame 494 with Frame 495: SSIM = 0.5591
# Comparing Frame 495 with Frame 496: SSIM = 0.5661
# Comparing Frame 496 with Frame 497: SSIM = 0.5629
# Comparing Frame 497 with Frame 498: SSIM = 0.5580
# Comparing Frame 498 with Frame 499: SSIM = 0.5507
# Comparing Frame 499 with Frame 500: SSIM = 0.5437
# Comparing Frame 500 with Frame 501: SSIM = 0.5343
# Comparing Frame 501 with Frame 502: SSIM = 0.5322
# Comparing Frame 502 with Frame 503: SSIM = 0.5318
# Comparing Frame 503 with Frame 504: SSIM = 0.5294
# Comparing Frame 504 with Frame 505: SSIM = 0.5337
# Comparing Frame 505 with Frame 506: SSIM = 0.5332
# Comparing Frame 506 with Frame 507: SSIM = 0.5096
# Comparing Frame 507 with Frame 508: SSIM = 0.5232
# Comparing Frame 508 with Frame 509: SSIM = 0.5531
# Comparing Frame 509 with Frame 510: SSIM = 0.5639
# Comparing Frame 510 with Frame 511: SSIM = 0.5584
# Comparing Frame 511 with Frame 512: SSIM = 0.5365
# Comparing Frame 512 with Frame 513: SSIM = 0.5380
# Comparing Frame 513 with Frame 514: SSIM = 0.5345
# Comparing Frame 514 with Frame 515: SSIM = 0.5287
# Comparing Frame 515 with Frame 516: SSIM = 0.5224
# Comparing Frame 516 with Frame 517: SSIM = 0.5167
# Comparing Frame 517 with Frame 518: SSIM = 0.5137
# Comparing Frame 518 with Frame 519: SSIM = 0.5227
# Comparing Frame 519 with Frame 520: SSIM = 0.5819
# Comparing Frame 520 with Frame 521: SSIM = 0.5827
# Comparing Frame 521 with Frame 522: SSIM = 0.6258
# Comparing Frame 522 with Frame 523: SSIM = 0.6473
# Comparing Frame 523 with Frame 524: SSIM = 0.7369
# Comparing Frame 524 with Frame 525: SSIM = 0.7144
# Comparing Frame 525 with Frame 526: SSIM = 0.6740
# Comparing Frame 526 with Frame 527: SSIM = 0.7254
# Comparing Frame 527 with Frame 528: SSIM = 0.7122
# Comparing Frame 528 with Frame 529: SSIM = 0.7067
# Comparing Frame 529 with Frame 530: SSIM = 0.7257
# Comparing Frame 530 with Frame 531: SSIM = 0.7561
# Comparing Frame 530 with Frame 532: SSIM = 0.6204
# Comparing Frame 532 with Frame 533: SSIM = 0.7298
# Comparing Frame 533 with Frame 534: SSIM = 0.6839
# Comparing Frame 534 with Frame 535: SSIM = 0.6665
# Comparing Frame 535 with Frame 536: SSIM = 0.6536
# Comparing Frame 536 with Frame 537: SSIM = 0.6461
# Comparing Frame 537 with Frame 538: SSIM = 0.6317
# Comparing Frame 538 with Frame 539: SSIM = 0.6181
# Comparing Frame 539 with Frame 540: SSIM = 0.6229
# Comparing Frame 540 with Frame 541: SSIM = 0.6268
# Comparing Frame 541 with Frame 542: SSIM = 0.6193
# Comparing Frame 542 with Frame 543: SSIM = 0.6290
# Comparing Frame 543 with Frame 544: SSIM = 0.6161
# Comparing Frame 544 with Frame 545: SSIM = 0.6115
# Comparing Frame 545 with Frame 546: SSIM = 0.6069
# Comparing Frame 546 with Frame 547: SSIM = 0.5929
# Comparing Frame 547 with Frame 548: SSIM = 0.5925
# Comparing Frame 548 with Frame 549: SSIM = 0.6553
# Comparing Frame 549 with Frame 550: SSIM = 0.6213
# Comparing Frame 550 with Frame 551: SSIM = 0.6392
# Comparing Frame 551 with Frame 552: SSIM = 0.6326
# Comparing Frame 552 with Frame 553: SSIM = 0.6230
# Comparing Frame 553 with Frame 554: SSIM = 0.6189
# Comparing Frame 554 with Frame 555: SSIM = 0.6566
# Comparing Frame 555 with Frame 556: SSIM = 0.7073
# Comparing Frame 556 with Frame 557: SSIM = 0.6662
# Comparing Frame 557 with Frame 558: SSIM = 0.6483
# Comparing Frame 558 with Frame 559: SSIM = 0.6555
# Comparing Frame 559 with Frame 560: SSIM = 0.6671
# Comparing Frame 560 with Frame 561: SSIM = 0.6719
# Comparing Frame 561 with Frame 562: SSIM = 0.6697
# Comparing Frame 562 with Frame 563: SSIM = 0.6874
# Comparing Frame 563 with Frame 564: SSIM = 0.7037
# Comparing Frame 564 with Frame 565: SSIM = 0.7105
# Comparing Frame 565 with Frame 566: SSIM = 0.7048
# Comparing Frame 566 with Frame 567: SSIM = 0.6901
# Comparing Frame 567 with Frame 568: SSIM = 0.6811
# Comparing Frame 568 with Frame 569: SSIM = 0.6876
# Comparing Frame 569 with Frame 570: SSIM = 0.6837
# Comparing Frame 570 with Frame 571: SSIM = 0.6521
# Comparing Frame 571 with Frame 572: SSIM = 0.6682
# Comparing Frame 572 with Frame 573: SSIM = 0.6676
# Comparing Frame 573 with Frame 574: SSIM = 0.6750
# Comparing Frame 574 with Frame 575: SSIM = 0.6384
# Comparing Frame 575 with Frame 576: SSIM = 0.6396
# Comparing Frame 576 with Frame 577: SSIM = 0.6496
# Comparing Frame 577 with Frame 578: SSIM = 0.6266
# Comparing Frame 578 with Frame 579: SSIM = 0.6259
# Comparing Frame 579 with Frame 580: SSIM = 0.6181
# Comparing Frame 580 with Frame 581: SSIM = 0.6303
# Comparing Frame 581 with Frame 582: SSIM = 0.6302
# Comparing Frame 582 with Frame 583: SSIM = 0.6302
# Comparing Frame 583 with Frame 584: SSIM = 0.6308
# Comparing Frame 584 with Frame 585: SSIM = 0.6438
# Comparing Frame 585 with Frame 586: SSIM = 0.6225
# Comparing Frame 586 with Frame 587: SSIM = 0.5997
# Comparing Frame 587 with Frame 588: SSIM = 0.5531
# Comparing Frame 588 with Frame 589: SSIM = 0.5801
# Comparing Frame 589 with Frame 590: SSIM = 0.5996
# Comparing Frame 590 with Frame 591: SSIM = 0.6321
# Comparing Frame 591 with Frame 592: SSIM = 0.6280
# Comparing Frame 592 with Frame 593: SSIM = 0.6337
# Comparing Frame 593 with Frame 594: SSIM = 0.6135
# Comparing Frame 594 with Frame 595: SSIM = 0.5934
# Comparing Frame 595 with Frame 596: SSIM = 0.5921
# Comparing Frame 596 with Frame 597: SSIM = 0.5838
# Comparing Frame 597 with Frame 598: SSIM = 0.5698
# Comparing Frame 598 with Frame 599: SSIM = 0.5770
# Comparing Frame 599 with Frame 600: SSIM = 0.5720
# Comparing Frame 600 with Frame 601: SSIM = 0.5813
# Comparing Frame 601 with Frame 602: SSIM = 0.5833
# Comparing Frame 602 with Frame 603: SSIM = 0.5583
# Comparing Frame 603 with Frame 604: SSIM = 0.5486
# Comparing Frame 604 with Frame 605: SSIM = 0.5682
# Comparing Frame 605 with Frame 606: SSIM = 0.5612
# Comparing Frame 606 with Frame 607: SSIM = 0.5618
# Comparing Frame 607 with Frame 608: SSIM = 0.5606
# Comparing Frame 608 with Frame 609: SSIM = 0.5466
# Comparing Frame 609 with Frame 610: SSIM = 0.5475
# Comparing Frame 610 with Frame 611: SSIM = 0.5487
# Comparing Frame 611 with Frame 612: SSIM = 0.5501
# Comparing Frame 612 with Frame 613: SSIM = 0.5548
# Comparing Frame 613 with Frame 614: SSIM = 0.5595
# Comparing Frame 614 with Frame 615: SSIM = 0.5537
# Comparing Frame 615 with Frame 616: SSIM = 0.5593
# Comparing Frame 616 with Frame 617: SSIM = 0.5647
# Comparing Frame 617 with Frame 618: SSIM = 0.5668
# Comparing Frame 618 with Frame 619: SSIM = 0.5736
# Comparing Frame 619 with Frame 620: SSIM = 0.6020
# Comparing Frame 620 with Frame 621: SSIM = 0.6152
# Comparing Frame 621 with Frame 622: SSIM = 0.6165
# Comparing Frame 622 with Frame 623: SSIM = 0.6152
# Comparing Frame 623 with Frame 624: SSIM = 0.6163
# Comparing Frame 624 with Frame 625: SSIM = 0.6214
# Comparing Frame 625 with Frame 626: SSIM = 0.6239
# Comparing Frame 626 with Frame 627: SSIM = 0.6436
# Comparing Frame 627 with Frame 628: SSIM = 0.6438
# Comparing Frame 628 with Frame 629: SSIM = 0.6493
# Comparing Frame 629 with Frame 630: SSIM = 0.6542
# Comparing Frame 630 with Frame 631: SSIM = 0.6774
# Comparing Frame 631 with Frame 632: SSIM = 0.7034
# Comparing Frame 632 with Frame 633: SSIM = 0.7356
# Comparing Frame 633 with Frame 634: SSIM = 0.7560
# Comparing Frame 633 with Frame 635: SSIM = 0.5559
# Comparing Frame 635 with Frame 636: SSIM = 0.7838
# Comparing Frame 635 with Frame 637: SSIM = 0.6103
# Comparing Frame 637 with Frame 638: SSIM = 0.8196
# Comparing Frame 637 with Frame 639: SSIM = 0.6557
# Comparing Frame 639 with Frame 640: SSIM = 0.8738
# Comparing Frame 639 with Frame 641: SSIM = 0.7585
# Comparing Frame 639 with Frame 642: SSIM = 0.7127
# Comparing Frame 642 with Frame 643: SSIM = 0.9141
# Comparing Frame 642 with Frame 644: SSIM = 0.8326
# Comparing Frame 642 with Frame 645: SSIM = 0.6938
# Comparing Frame 645 with Frame 646: SSIM = 0.8333
# Comparing Frame 645 with Frame 647: SSIM = 0.6044
# Comparing Frame 647 with Frame 648: SSIM = 0.8074
# Comparing Frame 647 with Frame 649: SSIM = 0.5999
# Comparing Frame 649 with Frame 650: SSIM = 0.8656
# Comparing Frame 649 with Frame 651: SSIM = 0.6805
# Comparing Frame 651 with Frame 652: SSIM = 0.8931
# Comparing Frame 651 with Frame 653: SSIM = 0.7828
# Comparing Frame 651 with Frame 654: SSIM = 0.7344
# Comparing Frame 654 with Frame 655: SSIM = 0.9437
# Comparing Frame 654 with Frame 656: SSIM = 0.9045
# Comparing Frame 654 with Frame 657: SSIM = 0.8448
# Comparing Frame 654 with Frame 658: SSIM = 0.8162
# Comparing Frame 654 with Frame 659: SSIM = 0.7772
# Comparing Frame 654 with Frame 660: SSIM = 0.7658
# Comparing Frame 654 with Frame 661: SSIM = 0.7428
# Comparing Frame 661 with Frame 662: SSIM = 0.9767
# Comparing Frame 661 with Frame 663: SSIM = 0.9580
# Comparing Frame 661 with Frame 664: SSIM = 0.9453
# Comparing Frame 661 with Frame 665: SSIM = 0.9208
# Comparing Frame 661 with Frame 666: SSIM = 0.8885
# Comparing Frame 661 with Frame 667: SSIM = 0.7885
# Comparing Frame 661 with Frame 668: SSIM = 0.7102
# Comparing Frame 668 with Frame 669: SSIM = 0.8747
# Comparing Frame 668 with Frame 670: SSIM = 0.6861
# Comparing Frame 670 with Frame 671: SSIM = 0.8362
# Comparing Frame 670 with Frame 672: SSIM = 0.6631
# Comparing Frame 672 with Frame 673: SSIM = 0.9007
# Comparing Frame 672 with Frame 674: SSIM = 0.8029
# Comparing Frame 672 with Frame 675: SSIM = 0.7588
# Comparing Frame 672 with Frame 676: SSIM = 0.7834
# Comparing Frame 672 with Frame 677: SSIM = 0.7887
# Comparing Frame 672 with Frame 678: SSIM = 0.8157
# Comparing Frame 672 with Frame 679: SSIM = 0.7967
# Comparing Frame 672 with Frame 680: SSIM = 0.7974
# Comparing Frame 672 with Frame 681: SSIM = 0.7927
# Comparing Frame 672 with Frame 682: SSIM = 0.7891
# Comparing Frame 672 with Frame 683: SSIM = 0.7611
# Comparing Frame 672 with Frame 684: SSIM = 0.7635
# Comparing Frame 672 with Frame 685: SSIM = 0.7621
# Comparing Frame 672 with Frame 686: SSIM = 0.7663
# Comparing Frame 672 with Frame 687: SSIM = 0.7665
# Comparing Frame 672 with Frame 688: SSIM = 0.7688
# Comparing Frame 672 with Frame 689: SSIM = 0.7677
# Comparing Frame 672 with Frame 690: SSIM = 0.7717
# Comparing Frame 672 with Frame 691: SSIM = 0.7711
# Comparing Frame 672 with Frame 692: SSIM = 0.7720
# Comparing Frame 672 with Frame 693: SSIM = 0.7708
# Comparing Frame 672 with Frame 694: SSIM = 0.7720
# Comparing Frame 672 with Frame 695: SSIM = 0.7708
# Comparing Frame 672 with Frame 696: SSIM = 0.7708
# Comparing Frame 672 with Frame 697: SSIM = 0.7684
# Comparing Frame 672 with Frame 698: SSIM = 0.7691
# Comparing Frame 672 with Frame 699: SSIM = 0.7684
# Comparing Frame 672 with Frame 700: SSIM = 0.7705
# Comparing Frame 672 with Frame 701: SSIM = 0.7698
# Comparing Frame 672 with Frame 702: SSIM = 0.7697
# Comparing Frame 672 with Frame 703: SSIM = 0.7675
# Comparing Frame 672 with Frame 704: SSIM = 0.7678
# Comparing Frame 672 with Frame 705: SSIM = 0.7650
# Comparing Frame 672 with Frame 706: SSIM = 0.7663
# Comparing Frame 672 with Frame 707: SSIM = 0.7658
# Comparing Frame 672 with Frame 708: SSIM = 0.7682
# Comparing Frame 672 with Frame 709: SSIM = 0.7678
# Comparing Frame 672 with Frame 710: SSIM = 0.7700
# Comparing Frame 672 with Frame 711: SSIM = 0.7696
# Comparing Frame 672 with Frame 712: SSIM = 0.7702
# Comparing Frame 672 with Frame 713: SSIM = 0.7672
# Comparing Frame 672 with Frame 714: SSIM = 0.7679
# Comparing Frame 672 with Frame 715: SSIM = 0.7628
# Comparing Frame 672 with Frame 716: SSIM = 0.7647
# Comparing Frame 672 with Frame 717: SSIM = 0.7640
# Comparing Frame 672 with Frame 718: SSIM = 0.7650
# Comparing Frame 672 with Frame 719: SSIM = 0.7641
# Comparing Frame 672 with Frame 720: SSIM = 0.7662
# Comparing Frame 672 with Frame 721: SSIM = 0.7641
# Comparing Frame 672 with Frame 722: SSIM = 0.7652
# Comparing Frame 672 with Frame 723: SSIM = 0.7648
# Comparing Frame 672 with Frame 724: SSIM = 0.7662
# Comparing Frame 672 with Frame 725: SSIM = 0.7657
# Comparing Frame 672 with Frame 726: SSIM = 0.7655
# Comparing Frame 672 with Frame 727: SSIM = 0.7643
# Comparing Frame 672 with Frame 728: SSIM = 0.7652
# Comparing Frame 672 with Frame 729: SSIM = 0.7632
# Comparing Frame 672 with Frame 730: SSIM = 0.7629
# Comparing Frame 672 with Frame 731: SSIM = 0.7615
# Comparing Frame 672 with Frame 732: SSIM = 0.7656
# Comparing Frame 672 with Frame 733: SSIM = 0.7658
# Comparing Frame 672 with Frame 734: SSIM = 0.7677
# Comparing Frame 672 with Frame 735: SSIM = 0.7676
# Comparing Frame 672 with Frame 736: SSIM = 0.7712
# Comparing Frame 672 with Frame 737: SSIM = 0.7698
# Comparing Frame 672 with Frame 738: SSIM = 0.7707
# Comparing Frame 672 with Frame 739: SSIM = 0.7687
# Comparing Frame 672 with Frame 740: SSIM = 0.7710
# Comparing Frame 672 with Frame 741: SSIM = 0.7716
# Comparing Frame 672 with Frame 742: SSIM = 0.7728
# Comparing Frame 672 with Frame 743: SSIM = 0.7712
# Comparing Frame 672 with Frame 744: SSIM = 0.7718
# Comparing Frame 672 with Frame 745: SSIM = 0.7697
# Comparing Frame 672 with Frame 746: SSIM = 0.7700
# Comparing Frame 672 with Frame 747: SSIM = 0.7640
# Comparing Frame 672 with Frame 748: SSIM = 0.7651
# Comparing Frame 672 with Frame 749: SSIM = 0.7629
# Comparing Frame 672 with Frame 750: SSIM = 0.7643
# Comparing Frame 672 with Frame 751: SSIM = 0.7630
# Comparing Frame 672 with Frame 752: SSIM = 0.7631
# Comparing Frame 672 with Frame 753: SSIM = 0.7629
# Comparing Frame 672 with Frame 754: SSIM = 0.7643
# Comparing Frame 672 with Frame 755: SSIM = 0.7633
# Comparing Frame 672 with Frame 756: SSIM = 0.7634
# Comparing Frame 672 with Frame 757: SSIM = 0.7627
# Comparing Frame 672 with Frame 758: SSIM = 0.7633
# Comparing Frame 672 with Frame 759: SSIM = 0.7634
# Comparing Frame 672 with Frame 760: SSIM = 0.7644
# Comparing Frame 672 with Frame 761: SSIM = 0.7635
# Comparing Frame 672 with Frame 762: SSIM = 0.7632
# Comparing Frame 672 with Frame 763: SSIM = 0.7619
# Comparing Frame 672 with Frame 764: SSIM = 0.7644
# Comparing Frame 672 with Frame 765: SSIM = 0.7620
# Comparing Frame 672 with Frame 766: SSIM = 0.7628
# Comparing Frame 672 with Frame 767: SSIM = 0.7621
# Comparing Frame 672 with Frame 768: SSIM = 0.7638
# Comparing Frame 672 with Frame 769: SSIM = 0.7622
# Comparing Frame 672 with Frame 770: SSIM = 0.7641
# Comparing Frame 672 with Frame 771: SSIM = 0.7623
# Comparing Frame 672 with Frame 772: SSIM = 0.7648
# Comparing Frame 672 with Frame 773: SSIM = 0.7642
# Comparing Frame 672 with Frame 774: SSIM = 0.7646
# Comparing Frame 672 with Frame 775: SSIM = 0.7637
# Comparing Frame 672 with Frame 776: SSIM = 0.7649
# Comparing Frame 672 with Frame 777: SSIM = 0.7628
# Comparing Frame 672 with Frame 778: SSIM = 0.7635
# Comparing Frame 672 with Frame 779: SSIM = 0.7595
# Comparing Frame 672 with Frame 780: SSIM = 0.7615
# Comparing Frame 672 with Frame 781: SSIM = 0.7608
# Comparing Frame 672 with Frame 782: SSIM = 0.7626
# Comparing Frame 672 with Frame 783: SSIM = 0.7615
# Comparing Frame 672 with Frame 784: SSIM = 0.7627
# Comparing Frame 672 with Frame 785: SSIM = 0.7620
# Comparing Frame 672 with Frame 786: SSIM = 0.7630
# Comparing Frame 672 with Frame 787: SSIM = 0.7626
# Comparing Frame 672 with Frame 788: SSIM = 0.7637
# Comparing Frame 672 with Frame 789: SSIM = 0.7634
# Comparing Frame 672 with Frame 790: SSIM = 0.7646
# Comparing Frame 672 with Frame 791: SSIM = 0.7641
# Comparing Frame 672 with Frame 792: SSIM = 0.7662
# Comparing Frame 672 with Frame 793: SSIM = 0.7645
# Comparing Frame 672 with Frame 794: SSIM = 0.7648
# Comparing Frame 672 with Frame 795: SSIM = 0.7673
# Comparing Frame 672 with Frame 796: SSIM = 0.7704
# Comparing Frame 672 with Frame 797: SSIM = 0.7709
# Comparing Frame 672 with Frame 798: SSIM = 0.7724
# Comparing Frame 672 with Frame 799: SSIM = 0.7726
# Comparing Frame 672 with Frame 800: SSIM = 0.7738
# Comparing Frame 672 with Frame 801: SSIM = 0.7729
# Comparing Frame 672 with Frame 802: SSIM = 0.7761
# Comparing Frame 672 with Frame 803: SSIM = 0.7758
# Comparing Frame 672 with Frame 804: SSIM = 0.7763
# Comparing Frame 672 with Frame 805: SSIM = 0.7761
# Comparing Frame 672 with Frame 806: SSIM = 0.7763
# Comparing Frame 672 with Frame 807: SSIM = 0.7752
# Comparing Frame 672 with Frame 808: SSIM = 0.7761
# Comparing Frame 672 with Frame 809: SSIM = 0.7744
# Comparing Frame 672 with Frame 810: SSIM = 0.7748
# Comparing Frame 672 with Frame 811: SSIM = 0.7651
# Comparing Frame 672 with Frame 812: SSIM = 0.7676
# Comparing Frame 672 with Frame 813: SSIM = 0.7662
# Comparing Frame 672 with Frame 814: SSIM = 0.7684
# Comparing Frame 672 with Frame 815: SSIM = 0.7676
# Comparing Frame 672 with Frame 816: SSIM = 0.7681
# Comparing Frame 672 with Frame 817: SSIM = 0.7672
# Comparing Frame 672 with Frame 818: SSIM = 0.7681
# Comparing Frame 672 with Frame 819: SSIM = 0.7666
# Comparing Frame 672 with Frame 820: SSIM = 0.7671
# Comparing Frame 672 with Frame 821: SSIM = 0.7664
# Comparing Frame 672 with Frame 822: SSIM = 0.7661
# Comparing Frame 672 with Frame 823: SSIM = 0.7638
# Comparing Frame 672 with Frame 824: SSIM = 0.7644
# Comparing Frame 672 with Frame 825: SSIM = 0.7620
# Comparing Frame 672 with Frame 826: SSIM = 0.7622
# Comparing Frame 672 with Frame 827: SSIM = 0.7621
# Comparing Frame 672 with Frame 828: SSIM = 0.7632
# Comparing Frame 672 with Frame 829: SSIM = 0.7608
# Comparing Frame 672 with Frame 830: SSIM = 0.7626
# Comparing Frame 672 with Frame 831: SSIM = 0.7613
# Comparing Frame 672 with Frame 832: SSIM = 0.7618
# Comparing Frame 672 with Frame 833: SSIM = 0.7598
# Comparing Frame 672 with Frame 834: SSIM = 0.7608
# Comparing Frame 672 with Frame 835: SSIM = 0.7600
# Comparing Frame 672 with Frame 836: SSIM = 0.7618
# Comparing Frame 672 with Frame 837: SSIM = 0.7623
# Comparing Frame 672 with Frame 838: SSIM = 0.7640
# Comparing Frame 672 with Frame 839: SSIM = 0.7620
# Comparing Frame 672 with Frame 840: SSIM = 0.7633
# Comparing Frame 672 with Frame 841: SSIM = 0.7608
# Comparing Frame 672 with Frame 842: SSIM = 0.7591
# Comparing Frame 672 with Frame 843: SSIM = 0.7516
# Comparing Frame 672 with Frame 844: SSIM = 0.7541
# Comparing Frame 672 with Frame 845: SSIM = 0.7547
# Comparing Frame 672 with Frame 846: SSIM = 0.7563
# Comparing Frame 672 with Frame 847: SSIM = 0.7558
# Comparing Frame 672 with Frame 848: SSIM = 0.7568
# Comparing Frame 672 with Frame 849: SSIM = 0.7547
# Comparing Frame 672 with Frame 850: SSIM = 0.7558
# Comparing Frame 672 with Frame 851: SSIM = 0.7543
# Comparing Frame 672 with Frame 852: SSIM = 0.7549
# Comparing Frame 672 with Frame 853: SSIM = 0.7545
# Comparing Frame 672 with Frame 854: SSIM = 0.7561
# Comparing Frame 672 with Frame 855: SSIM = 0.7564
# Comparing Frame 672 with Frame 856: SSIM = 0.7596
# Comparing Frame 672 with Frame 857: SSIM = 0.7591
# Comparing Frame 672 with Frame 858: SSIM = 0.7592
# Comparing Frame 672 with Frame 859: SSIM = 0.7545
# Comparing Frame 672 with Frame 860: SSIM = 0.7556
# Comparing Frame 672 with Frame 861: SSIM = 0.7560
# Comparing Frame 672 with Frame 862: SSIM = 0.7579
# Comparing Frame 672 with Frame 863: SSIM = 0.7574
# Comparing Frame 672 with Frame 864: SSIM = 0.7598
# Comparing Frame 672 with Frame 865: SSIM = 0.7586
# Comparing Frame 672 with Frame 866: SSIM = 0.7585
# Comparing Frame 672 with Frame 867: SSIM = 0.7563
# Comparing Frame 672 with Frame 868: SSIM = 0.7576
# Comparing Frame 672 with Frame 869: SSIM = 0.7561
# Comparing Frame 672 with Frame 870: SSIM = 0.7557
# Comparing Frame 672 with Frame 871: SSIM = 0.7552
# Comparing Frame 672 with Frame 872: SSIM = 0.7565
# Comparing Frame 672 with Frame 873: SSIM = 0.7549
# Comparing Frame 672 with Frame 874: SSIM = 0.7553
# Comparing Frame 672 with Frame 875: SSIM = 0.7556
# Comparing Frame 672 with Frame 876: SSIM = 0.7597
# Comparing Frame 672 with Frame 877: SSIM = 0.7591
# Comparing Frame 672 with Frame 878: SSIM = 0.7614
# Comparing Frame 672 with Frame 879: SSIM = 0.7603
# Comparing Frame 672 with Frame 880: SSIM = 0.7606
# Comparing Frame 672 with Frame 881: SSIM = 0.7604
# Comparing Frame 672 with Frame 882: SSIM = 0.7614
# Comparing Frame 672 with Frame 883: SSIM = 0.7593
# Comparing Frame 672 with Frame 884: SSIM = 0.7598
# Comparing Frame 672 with Frame 885: SSIM = 0.7594
# Comparing Frame 672 with Frame 886: SSIM = 0.7608
# Comparing Frame 672 with Frame 887: SSIM = 0.7598
# Comparing Frame 672 with Frame 888: SSIM = 0.7606
# Comparing Frame 672 with Frame 889: SSIM = 0.7585
# Comparing Frame 672 with Frame 890: SSIM = 0.7580
# Comparing Frame 672 with Frame 891: SSIM = 0.7515
# Comparing Frame 672 with Frame 892: SSIM = 0.7557
# Comparing Frame 672 with Frame 893: SSIM = 0.7551
# Comparing Frame 672 with Frame 894: SSIM = 0.7564
# Comparing Frame 672 with Frame 895: SSIM = 0.7554
# Comparing Frame 672 with Frame 896: SSIM = 0.7562
# Comparing Frame 672 with Frame 897: SSIM = 0.7554
# Comparing Frame 672 with Frame 898: SSIM = 0.7577
# Comparing Frame 672 with Frame 899: SSIM = 0.7552
# Comparing Frame 672 with Frame 900: SSIM = 0.7573
# Comparing Frame 672 with Frame 901: SSIM = 0.7572
# Comparing Frame 672 with Frame 902: SSIM = 0.7588
# Comparing Frame 672 with Frame 903: SSIM = 0.7578
# Comparing Frame 672 with Frame 904: SSIM = 0.7595
# Comparing Frame 672 with Frame 905: SSIM = 0.7587
# Comparing Frame 672 with Frame 906: SSIM = 0.7595
# Comparing Frame 672 with Frame 907: SSIM = 0.7577
# Comparing Frame 672 with Frame 908: SSIM = 0.7600
# Comparing Frame 672 with Frame 909: SSIM = 0.7588
# Comparing Frame 672 with Frame 910: SSIM = 0.7597
# Comparing Frame 672 with Frame 911: SSIM = 0.7594
# Comparing Frame 672 with Frame 912: SSIM = 0.7599
# Comparing Frame 672 with Frame 913: SSIM = 0.7581
# Comparing Frame 672 with Frame 914: SSIM = 0.7586
# Comparing Frame 672 with Frame 915: SSIM = 0.7572
# Comparing Frame 672 with Frame 916: SSIM = 0.7590
# Comparing Frame 672 with Frame 917: SSIM = 0.7591
# Comparing Frame 672 with Frame 918: SSIM = 0.7598
# Comparing Frame 672 with Frame 919: SSIM = 0.7591
# Comparing Frame 672 with Frame 920: SSIM = 0.7602
# Comparing Frame 672 with Frame 921: SSIM = 0.7588
# Comparing Frame 672 with Frame 922: SSIM = 0.7602
# Comparing Frame 672 with Frame 923: SSIM = 0.7573
# Comparing Frame 672 with Frame 924: SSIM = 0.7607
# Comparing Frame 672 with Frame 925: SSIM = 0.7592
# Comparing Frame 672 with Frame 926: SSIM = 0.7606
# Comparing Frame 672 with Frame 927: SSIM = 0.7603
# Comparing Frame 672 with Frame 928: SSIM = 0.7617
# Comparing Frame 672 with Frame 929: SSIM = 0.7614
# Comparing Frame 672 with Frame 930: SSIM = 0.7636
# Comparing Frame 672 with Frame 931: SSIM = 0.7628
# Comparing Frame 672 with Frame 932: SSIM = 0.7644
# Comparing Frame 672 with Frame 933: SSIM = 0.7636
# Comparing Frame 672 with Frame 934: SSIM = 0.7651
# Comparing Frame 672 with Frame 935: SSIM = 0.7639
# Comparing Frame 672 with Frame 936: SSIM = 0.7654
# Comparing Frame 672 with Frame 937: SSIM = 0.7647
# Comparing Frame 672 with Frame 938: SSIM = 0.7663
# Comparing Frame 672 with Frame 939: SSIM = 0.7623
# Comparing Frame 672 with Frame 940: SSIM = 0.7659
# Comparing Frame 672 with Frame 941: SSIM = 0.7645
# Comparing Frame 672 with Frame 942: SSIM = 0.7662
# Comparing Frame 672 with Frame 943: SSIM = 0.7650
# Comparing Frame 672 with Frame 944: SSIM = 0.7664
# Comparing Frame 672 with Frame 945: SSIM = 0.7659
# Comparing Frame 672 with Frame 946: SSIM = 0.7679
# Comparing Frame 672 with Frame 947: SSIM = 0.7658
# Comparing Frame 672 with Frame 948: SSIM = 0.7669
# Comparing Frame 672 with Frame 949: SSIM = 0.7659
# Comparing Frame 672 with Frame 950: SSIM = 0.7665
# Comparing Frame 672 with Frame 951: SSIM = 0.7657
# Comparing Frame 672 with Frame 952: SSIM = 0.7673
# Comparing Frame 672 with Frame 953: SSIM = 0.7660
# Comparing Frame 672 with Frame 954: SSIM = 0.7662
# Comparing Frame 672 with Frame 955: SSIM = 0.7659
# Comparing Frame 672 with Frame 956: SSIM = 0.7682
# Comparing Frame 672 with Frame 957: SSIM = 0.7675
# Comparing Frame 672 with Frame 958: SSIM = 0.7701
# Comparing Frame 672 with Frame 959: SSIM = 0.7699
# Comparing Frame 672 with Frame 960: SSIM = 0.7719
# Comparing Frame 672 with Frame 961: SSIM = 0.7711
# Comparing Frame 672 with Frame 962: SSIM = 0.7725
# Comparing Frame 672 with Frame 963: SSIM = 0.7710
# Comparing Frame 672 with Frame 964: SSIM = 0.7724
# Comparing Frame 672 with Frame 965: SSIM = 0.7730
# Comparing Frame 672 with Frame 966: SSIM = 0.7741
# Comparing Frame 672 with Frame 967: SSIM = 0.7737
# Comparing Frame 672 with Frame 968: SSIM = 0.7757
# Comparing Frame 672 with Frame 969: SSIM = 0.7752
# Comparing Frame 672 with Frame 970: SSIM = 0.7763
# Comparing Frame 672 with Frame 971: SSIM = 0.7731
# Comparing Frame 672 with Frame 972: SSIM = 0.7755
# Comparing Frame 672 with Frame 973: SSIM = 0.7741
# Comparing Frame 672 with Frame 974: SSIM = 0.7758
# Comparing Frame 672 with Frame 975: SSIM = 0.7748
# Comparing Frame 672 with Frame 976: SSIM = 0.7759
# Comparing Frame 672 with Frame 977: SSIM = 0.7748
# Comparing Frame 672 with Frame 978: SSIM = 0.7755
# Comparing Frame 672 with Frame 979: SSIM = 0.7740
# Comparing Frame 672 with Frame 980: SSIM = 0.7750
# Comparing Frame 672 with Frame 981: SSIM = 0.7736
# Comparing Frame 672 with Frame 982: SSIM = 0.7745
# Comparing Frame 672 with Frame 983: SSIM = 0.7740
# Comparing Frame 672 with Frame 984: SSIM = 0.7752
# Comparing Frame 672 with Frame 985: SSIM = 0.7734
# Comparing Frame 672 with Frame 986: SSIM = 0.7736
# Comparing Frame 672 with Frame 987: SSIM = 0.7721
# Comparing Frame 672 with Frame 988: SSIM = 0.7746
# Comparing Frame 672 with Frame 989: SSIM = 0.7724
# Comparing Frame 672 with Frame 990: SSIM = 0.7732
# Comparing Frame 672 with Frame 991: SSIM = 0.7716
# Comparing Frame 672 with Frame 992: SSIM = 0.7727
# Comparing Frame 672 with Frame 993: SSIM = 0.7711
# Comparing Frame 672 with Frame 994: SSIM = 0.7720
# Comparing Frame 672 with Frame 995: SSIM = 0.7700
# Comparing Frame 672 with Frame 996: SSIM = 0.7709
# Comparing Frame 672 with Frame 997: SSIM = 0.7697
# Comparing Frame 672 with Frame 998: SSIM = 0.7708
# Comparing Frame 672 with Frame 999: SSIM = 0.7703
# Comparing Frame 672 with Frame 1000: SSIM = 0.7716
# Comparing Frame 672 with Frame 1001: SSIM = 0.7699
# Comparing Frame 672 with Frame 1002: SSIM = 0.7706
# Comparing Frame 672 with Frame 1003: SSIM = 0.7636
# Comparing Frame 672 with Frame 1004: SSIM = 0.7664
# Comparing Frame 672 with Frame 1005: SSIM = 0.7652
# Comparing Frame 672 with Frame 1006: SSIM = 0.7672
# Comparing Frame 672 with Frame 1007: SSIM = 0.7664
# Comparing Frame 672 with Frame 1008: SSIM = 0.7669
# Comparing Frame 672 with Frame 1009: SSIM = 0.7652
# Comparing Frame 672 with Frame 1010: SSIM = 0.7663
# Comparing Frame 672 with Frame 1011: SSIM = 0.7654
# Comparing Frame 672 with Frame 1012: SSIM = 0.7672
# Comparing Frame 672 with Frame 1013: SSIM = 0.7666
# Comparing Frame 672 with Frame 1014: SSIM = 0.7676
# Comparing Frame 672 with Frame 1015: SSIM = 0.7672
# Comparing Frame 672 with Frame 1016: SSIM = 0.7691
# Comparing Frame 672 with Frame 1017: SSIM = 0.7669
# Comparing Frame 672 with Frame 1018: SSIM = 0.7675
# Comparing Frame 672 with Frame 1019: SSIM = 0.7634
# Comparing Frame 672 with Frame 1020: SSIM = 0.7654
# Comparing Frame 672 with Frame 1021: SSIM = 0.7636
# Comparing Frame 672 with Frame 1022: SSIM = 0.7663
# Comparing Frame 672 with Frame 1023: SSIM = 0.7660
# Comparing Frame 672 with Frame 1024: SSIM = 0.7673
# Comparing Frame 672 with Frame 1025: SSIM = 0.7659
# Comparing Frame 672 with Frame 1026: SSIM = 0.7676
# Comparing Frame 672 with Frame 1027: SSIM = 0.7659
# Comparing Frame 672 with Frame 1028: SSIM = 0.7669
# Comparing Frame 672 with Frame 1029: SSIM = 0.7650
# Comparing Frame 672 with Frame 1030: SSIM = 0.7651
# Comparing Frame 672 with Frame 1031: SSIM = 0.7633
# Comparing Frame 672 with Frame 1032: SSIM = 0.7637
# Comparing Frame 672 with Frame 1033: SSIM = 0.7613
# Comparing Frame 672 with Frame 1034: SSIM = 0.7607
# Comparing Frame 672 with Frame 1035: SSIM = 0.7585
# Comparing Frame 672 with Frame 1036: SSIM = 0.7622
# Comparing Frame 672 with Frame 1037: SSIM = 0.7615
# Comparing Frame 672 with Frame 1038: SSIM = 0.7638
# Comparing Frame 672 with Frame 1039: SSIM = 0.7626
# Comparing Frame 672 with Frame 1040: SSIM = 0.7657
# Comparing Frame 672 with Frame 1041: SSIM = 0.7663
# Comparing Frame 672 with Frame 1042: SSIM = 0.7678
# Comparing Frame 672 with Frame 1043: SSIM = 0.7664
# Comparing Frame 672 with Frame 1044: SSIM = 0.7677
# Comparing Frame 672 with Frame 1045: SSIM = 0.7669
# Comparing Frame 672 with Frame 1046: SSIM = 0.7677
# Comparing Frame 672 with Frame 1047: SSIM = 0.7674
# Comparing Frame 672 with Frame 1048: SSIM = 0.7688
# Comparing Frame 672 with Frame 1049: SSIM = 0.7675
# Comparing Frame 672 with Frame 1050: SSIM = 0.7668
# Comparing Frame 672 with Frame 1051: SSIM = 0.7588
# Comparing Frame 672 with Frame 1052: SSIM = 0.7619
# Comparing Frame 672 with Frame 1053: SSIM = 0.7614
# Comparing Frame 672 with Frame 1054: SSIM = 0.7631
# Comparing Frame 672 with Frame 1055: SSIM = 0.7623
# Comparing Frame 672 with Frame 1056: SSIM = 0.7644
# Comparing Frame 672 with Frame 1057: SSIM = 0.7630
# Comparing Frame 672 with Frame 1058: SSIM = 0.7649
# Comparing Frame 672 with Frame 1059: SSIM = 0.7635
# Comparing Frame 672 with Frame 1060: SSIM = 0.7645
# Comparing Frame 672 with Frame 1061: SSIM = 0.7634
# Comparing Frame 672 with Frame 1062: SSIM = 0.7634
# Comparing Frame 672 with Frame 1063: SSIM = 0.7621
# Comparing Frame 672 with Frame 1064: SSIM = 0.7635
# Comparing Frame 672 with Frame 1065: SSIM = 0.7620
# Comparing Frame 672 with Frame 1066: SSIM = 0.7628
# Comparing Frame 672 with Frame 1067: SSIM = 0.7610
# Comparing Frame 672 with Frame 1068: SSIM = 0.7633
# Comparing Frame 672 with Frame 1069: SSIM = 0.7622
# Comparing Frame 672 with Frame 1070: SSIM = 0.7650
# Comparing Frame 672 with Frame 1071: SSIM = 0.7644
# Comparing Frame 672 with Frame 1072: SSIM = 0.7659
# Comparing Frame 672 with Frame 1073: SSIM = 0.7649
# Comparing Frame 672 with Frame 1074: SSIM = 0.7665
# Comparing Frame 672 with Frame 1075: SSIM = 0.7656
# Comparing Frame 672 with Frame 1076: SSIM = 0.7672
# Comparing Frame 672 with Frame 1077: SSIM = 0.7671
# Comparing Frame 672 with Frame 1078: SSIM = 0.7685
# Comparing Frame 672 with Frame 1079: SSIM = 0.7680
# Comparing Frame 672 with Frame 1080: SSIM = 0.7693
# Comparing Frame 672 with Frame 1081: SSIM = 0.7669
# Comparing Frame 672 with Frame 1082: SSIM = 0.7669
# Comparing Frame 672 with Frame 1083: SSIM = 0.7645
# Comparing Frame 672 with Frame 1084: SSIM = 0.7676
# Comparing Frame 672 with Frame 1085: SSIM = 0.7660
# Comparing Frame 672 with Frame 1086: SSIM = 0.7677
# Comparing Frame 672 with Frame 1087: SSIM = 0.7670
# Comparing Frame 672 with Frame 1088: SSIM = 0.7686
# Comparing Frame 672 with Frame 1089: SSIM = 0.7680
# Comparing Frame 672 with Frame 1090: SSIM = 0.7690
# Comparing Frame 672 with Frame 1091: SSIM = 0.7668
# Comparing Frame 672 with Frame 1092: SSIM = 0.7672
# Comparing Frame 672 with Frame 1093: SSIM = 0.7656
# Comparing Frame 672 with Frame 1094: SSIM = 0.7671
# Comparing Frame 672 with Frame 1095: SSIM = 0.7666
# Comparing Frame 672 with Frame 1096: SSIM = 0.7675
# Comparing Frame 672 with Frame 1097: SSIM = 0.7652
# Comparing Frame 672 with Frame 1098: SSIM = 0.7647
# Comparing Frame 672 with Frame 1099: SSIM = 0.7588
# Comparing Frame 672 with Frame 1100: SSIM = 0.7636
# Comparing Frame 672 with Frame 1101: SSIM = 0.7633
# Comparing Frame 672 with Frame 1102: SSIM = 0.7657
# Comparing Frame 672 with Frame 1103: SSIM = 0.7624
# Comparing Frame 672 with Frame 1104: SSIM = 0.7613
# Comparing Frame 672 with Frame 1105: SSIM = 0.7568
# Comparing Frame 672 with Frame 1106: SSIM = 0.7539
# Comparing Frame 672 with Frame 1107: SSIM = 0.7482
# Comparing Frame 1107 with Frame 1108: SSIM = 0.9687
# Comparing Frame 1107 with Frame 1109: SSIM = 0.9473
# Comparing Frame 1107 with Frame 1110: SSIM = 0.9328
# Comparing Frame 1107 with Frame 1111: SSIM = 0.9207
# Comparing Frame 1107 with Frame 1112: SSIM = 0.9120
# Comparing Frame 1107 with Frame 1113: SSIM = 0.9036
# Comparing Frame 1107 with Frame 1114: SSIM = 0.8992
# Comparing Frame 1107 with Frame 1115: SSIM = 0.8683
# Comparing Frame 1107 with Frame 1116: SSIM = 0.8678
# Comparing Frame 1107 with Frame 1117: SSIM = 0.8638
# Comparing Frame 1107 with Frame 1118: SSIM = 0.8622
# Comparing Frame 1107 with Frame 1119: SSIM = 0.8584
# Comparing Frame 1107 with Frame 1120: SSIM = 0.8577
# Comparing Frame 1107 with Frame 1121: SSIM = 0.8549
# Comparing Frame 1107 with Frame 1122: SSIM = 0.8536
# Comparing Frame 1107 with Frame 1123: SSIM = 0.8505
# Comparing Frame 1107 with Frame 1124: SSIM = 0.8501
# Comparing Frame 1107 with Frame 1125: SSIM = 0.8493
# Comparing Frame 1107 with Frame 1126: SSIM = 0.8492
# Comparing Frame 1107 with Frame 1127: SSIM = 0.8472
# Comparing Frame 1107 with Frame 1128: SSIM = 0.8484
# Comparing Frame 1107 with Frame 1129: SSIM = 0.8473
# Comparing Frame 1107 with Frame 1130: SSIM = 0.8471
# Comparing Frame 1107 with Frame 1131: SSIM = 0.8414
# Comparing Frame 1107 with Frame 1132: SSIM = 0.8429
# Comparing Frame 1107 with Frame 1133: SSIM = 0.8402
# Comparing Frame 1107 with Frame 1134: SSIM = 0.8379
# Comparing Frame 1107 with Frame 1135: SSIM = 0.8352
# Comparing Frame 1107 with Frame 1136: SSIM = 0.8323
# Comparing Frame 1107 with Frame 1137: SSIM = 0.8245
# Comparing Frame 1107 with Frame 1138: SSIM = 0.8202
# Comparing Frame 1107 with Frame 1139: SSIM = 0.8088
# Comparing Frame 1107 with Frame 1140: SSIM = 0.7822
# Comparing Frame 1107 with Frame 1141: SSIM = 0.7383
# Comparing Frame 1141 with Frame 1142: SSIM = 0.9113
# Comparing Frame 1141 with Frame 1143: SSIM = 0.8157
# Comparing Frame 1141 with Frame 1144: SSIM = 0.7195
# Comparing Frame 1144 with Frame 1145: SSIM = 0.9030
# Comparing Frame 1144 with Frame 1146: SSIM = 0.8226
# Comparing Frame 1144 with Frame 1147: SSIM = 0.7267
# Comparing Frame 1147 with Frame 1148: SSIM = 0.9311
# Comparing Frame 1147 with Frame 1149: SSIM = 0.8862
# Comparing Frame 1147 with Frame 1150: SSIM = 0.8628
# Comparing Frame 1147 with Frame 1151: SSIM = 0.8328
# Comparing Frame 1147 with Frame 1152: SSIM = 0.8160
# Comparing Frame 1147 with Frame 1153: SSIM = 0.7887
# Comparing Frame 1147 with Frame 1154: SSIM = 0.7690
# Comparing Frame 1147 with Frame 1155: SSIM = 0.7435
# Comparing Frame 1155 with Frame 1156: SSIM = 0.9303
# Comparing Frame 1155 with Frame 1157: SSIM = 0.8947
# Comparing Frame 1155 with Frame 1158: SSIM = 0.8623
# Comparing Frame 1155 with Frame 1159: SSIM = 0.8247
# Comparing Frame 1155 with Frame 1160: SSIM = 0.7976
# Comparing Frame 1155 with Frame 1161: SSIM = 0.7659
# Comparing Frame 1155 with Frame 1162: SSIM = 0.7299
# Comparing Frame 1162 with Frame 1163: SSIM = 0.8694
# Comparing Frame 1162 with Frame 1164: SSIM = 0.8363
# Comparing Frame 1162 with Frame 1165: SSIM = 0.7913
# Comparing Frame 1162 with Frame 1166: SSIM = 0.7633
# Comparing Frame 1162 with Frame 1167: SSIM = 0.7280
# Comparing Frame 1167 with Frame 1168: SSIM = 0.9121
# Comparing Frame 1167 with Frame 1169: SSIM = 0.8484
# Comparing Frame 1167 with Frame 1170: SSIM = 0.7962
# Comparing Frame 1167 with Frame 1171: SSIM = 0.7471
# Comparing Frame 1171 with Frame 1172: SSIM = 0.9087
# Comparing Frame 1171 with Frame 1173: SSIM = 0.8407
# Comparing Frame 1171 with Frame 1174: SSIM = 0.7884
# Comparing Frame 1171 with Frame 1175: SSIM = 0.7418
# Comparing Frame 1175 with Frame 1176: SSIM = 0.9075
# Comparing Frame 1175 with Frame 1177: SSIM = 0.8355
# Comparing Frame 1175 with Frame 1178: SSIM = 0.7929
# Comparing Frame 1175 with Frame 1179: SSIM = 0.7389
# Comparing Frame 1179 with Frame 1180: SSIM = 0.9137
# Comparing Frame 1179 with Frame 1181: SSIM = 0.8482
# Comparing Frame 1179 with Frame 1182: SSIM = 0.8094
# Comparing Frame 1179 with Frame 1183: SSIM = 0.7615
# Comparing Frame 1179 with Frame 1184: SSIM = 0.7313
# Comparing Frame 1184 with Frame 1185: SSIM = 0.9211
# Comparing Frame 1184 with Frame 1186: SSIM = 0.8638
# Comparing Frame 1184 with Frame 1187: SSIM = 0.8049
# Comparing Frame 1184 with Frame 1188: SSIM = 0.7621
# Comparing Frame 1184 with Frame 1189: SSIM = 0.7212
# Comparing Frame 1189 with Frame 1190: SSIM = 0.9129
# Comparing Frame 1189 with Frame 1191: SSIM = 0.8352
# Comparing Frame 1189 with Frame 1192: SSIM = 0.7766
# Comparing Frame 1189 with Frame 1193: SSIM = 0.7241
# Comparing Frame 1193 with Frame 1194: SSIM = 0.8934
# Comparing Frame 1193 with Frame 1195: SSIM = 0.7870
# Comparing Frame 1193 with Frame 1196: SSIM = 0.7446
# Comparing Frame 1196 with Frame 1197: SSIM = 0.8886
# Comparing Frame 1196 with Frame 1198: SSIM = 0.8149
# Comparing Frame 1196 with Frame 1199: SSIM = 0.7437
# Comparing Frame 1199 with Frame 1200: SSIM = 0.8896
# Comparing Frame 1199 with Frame 1201: SSIM = 0.8057
# Comparing Frame 1199 with Frame 1202: SSIM = 0.7568
# Comparing Frame 1199 with Frame 1203: SSIM = 0.7082
# Comparing Frame 1203 with Frame 1204: SSIM = 0.8969
# Comparing Frame 1203 with Frame 1205: SSIM = 0.8042
# Processed video saved as: /content/Output_SSIM.mp4
# Total number of frames: 1206
# Number of frames skipped: 597
# Number of frames processed: 608
# % of frames skipped: 49.50%
# Frames processing per second: 5.74 FPS
# Total time taken to load frames: 10.857837 seconds
# Total processing time: 210.081676 seconds
# Total time (loading + processing): 220.939512 seconds
# Average time per frame comparison: 0.174342 seconds
# Total memory usage: Initial = 1233.13 MB, Final = 1757.84 MB
# Memory consumed during processing: 524.71 MB
# Average CPU usage during processing: 64.62%
# Total processing load: 1206 frames
